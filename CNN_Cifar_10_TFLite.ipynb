# %% [markdown]
# # CNN to classify Cifar-10 dataset (Images)

# %% [markdown]
# So far, we saw how to build a Dense Neural Network (DNN) that classified images of digits (MNIST) or even fashion images (Fashion-MNIST). Here we will instead, recognize the 10 classes of CIFAR ('airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship' and 'truck'). There are some key differences between these two image datasets that we need to take into account.
#
# First, while MNIST were 28x28 monochrome images (1 color channel), CIFAR is 32x32 color images (3 color channels).
#
# Second, MNIST images are simple, containing just the object centered in the image, with no background. Conversely, CIFAR ones are not centered and can have the object with a background, such as airplanes that might have a cloudy sky behind them! Those differences are the main reason to use a CNN instead of a DNN.

# %% [markdown]
# ## Import Libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, MaxPool2D, Flatten
from tensorflow.keras.callbacks import EarlyStopping

# %% [markdown]
# ## Import and Inspect Dataset

# %% [markdown]
# Cifar-10 repository: https://www.cs.toronto.edu/~kriz/cifar.html

# %%
cifar10 = tf.keras.datasets.cifar10
(train_images, train_labels), (test_images, test_labels) = cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 15s 0us/step

# %%
print(train_images.shape, train_labels.shape)
print(test_images.shape, test_labels.shape)
# Out:
# (50000, 32, 32, 3) (50000, 1)
# (10000, 32, 32, 3) (10000, 1)

# %% [markdown]
# - The image data shape is: `(#images, img_heigth, img_width, #channels)`, where channels are in RGB format (red, green, blue).
# - The labels shape is `(#images, label)`, where label goes from 0 to 9.

# %%
train_images[0]
# Out:
# array([[[ 59,  62,  63],
#         [ 43,  46,  45],
#         [ 50,  48,  43],
#         ...,
#         [158, 132, 108],
#         [152, 125, 102],
#         [148, 124, 103]],
#
#        [[ 16,  20,  20],
#         [  0,   0,   0],
#         [ 18,   8,   0],
#         ...,
#         [123,  88,  55],
#         [119,  83,  50],
#         [122,  87,  57]],
#
#        [[ 25,  24,  21],
#         [ 16,   7,   0],
#         [ 49,  27,   8],
#         ...,
#         [118,  84,  50],
#         [120,  84,  50],
#         [109,  73,  42]],
#
#        ...,
#
#        [[208, 170,  96],
#         [201, 153,  34],
#         [198, 161,  26],
#         ...,
#         [160, 133,  70],
#         [ 56,  31,   7],
#         [ 53,  34,  20]],
#
#        [[180, 139,  96],
#         [173, 123,  42],
#         [186, 144,  30],
#         ...,
#         [184, 148,  94],
#         [ 97,  62,  34],
#         [ 83,  53,  34]],
#
#        [[177, 144, 116],
#         [168, 129,  94],
#         [179, 142,  87],
#         ...,
#         [216, 184, 140],
#         [151, 118,  84],
#         [123,  92,  72]]], dtype=uint8)

# %%
plt.imshow(train_images[1]);

# %%
train_labels[1][0]
# Out:
# np.uint8(9)

# %% [markdown]
#     The CIFAR labels happen to be arrays, which is why you need the extra index

# %%
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# %%
class_names[9] # The List's index is the label
# Out:
# 'truck'

# %%
idx = train_labels[1][0]
class_names[idx]
# Out:
# 'truck'

# %%
print("\t", class_names[train_labels[1][0]])
plt.imshow(train_images[1])
plt.axis('off');
# Out:
# 	 truck

# %%
 def plot_train_img(img, size=2):
    label = train_labels[img][0]
    plt.figure(figsize=(size,size))
    print("Label {} - {}".format(label, class_names[label]))
    plt.imshow(train_images[img])
    plt.axis('off')
    plt.show()

# %%
plot_train_img(1)
# Out:
# Label 9 - truck

# %%
plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(train_images[i])
    plt.xlabel(class_names[train_labels[i][0]])
plt.show()

# %% [markdown]
# Note that images are in color, not centered and with different backgrounds

# %% [markdown]
# ## Preprocessing dataset

# %%
test_images.max()
# Out:
# np.uint8(255)

# %%
# Normalize pixel values to be between 0 and 1
train_images = train_images / 255.0
test_images = test_images / 255.0

# %%
test_images.max()
# Out:
# np.float64(1.0)

# %%
plt.hist(train_labels[:5_000]);

# %%
val_images = train_images[:5_000]
val_labels = train_labels[:5_000]
print(val_images.shape, val_labels.shape)
# Out:
# (5000, 32, 32, 3) (5000, 1)

# %%
train_images = train_images[5_000:]
train_labels = train_labels[5_000:]
print(train_images.shape, train_labels.shape)
# Out:
# (45000, 32, 32, 3) (45000, 1)

# %%
plt.hist(train_labels, alpha=0.5)
plt.hist(val_labels, alpha=0.5)
plt.hist(test_labels, alpha=0.5);

# %% [markdown]
# ## Create Model Arquitecture and Compile

# %% [markdown]
# On [Convolution layers](https://www.tensorflow.org/api_docs/python/tf/keras/layers/Conv2D),
# - strides is an integer or tuple/list of 2 integers, specifying the strides of the convolution along the height and width. Default (1,1).
# - padding: one of "valid" or "same" (case-insensitive). Default = 'valid'.
#   - "valid" means no padding.
#   - "same" results in padding with zeros evenly
# to the left/right or up/down of the input such that output has the same

# %%
model = Sequential()


model.add(Conv2D(
    filters=32,
    kernel_size=(3,3),
    activation='relu',
    input_shape=(32, 32, 3))
)
model.add(MaxPool2D(2, 2))

model.add(Conv2D(64, (3,3), activation='relu'))
model.add(MaxPool2D())

model.add(Flatten())
model.add(Dense(64, activation='relu'))
model.add(Dense(10, activation='softmax'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 32)        896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 2304)              0
# _________________________________________________________________
# dense (Dense)                (None, 64)                147520
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                650
# =================================================================
# Total params: 167,562
# Trainable params: 167,562
# Non-trainable params: 0
# _________________________________________________________________

# %%
LOSS = 'sparse_categorical_crossentropy'
OPTIMIZER = 'adam'

# Compile the model
model.compile(optimizer=OPTIMIZER,
              loss=LOSS,
              metrics=['accuracy'])

# %% [markdown]
# ## Training

# %%
NUM_EPOCHS = 20

early_stop = EarlyStopping(monitor='val_loss',patience=3)

# %%
# Fit the model
history = model.fit(train_images,
                    train_labels,
                    epochs=NUM_EPOCHS,
                    validation_data=(val_images, val_labels),
                    callbacks=[early_stop]
)
# Out:
# Epoch 1/20
# 1407/1407 [==============================] - 38s 6ms/step - loss: 1.5458 - accuracy: 0.4400 - val_loss: 1.2562 - val_accuracy: 0.5598
# Epoch 2/20
# 1407/1407 [==============================] - 8s 6ms/step - loss: 1.1790 - accuracy: 0.5857 - val_loss: 1.0949 - val_accuracy: 0.6180
# Epoch 3/20
# 1407/1407 [==============================] - 8s 6ms/step - loss: 1.0395 - accuracy: 0.6356 - val_loss: 0.9961 - val_accuracy: 0.6466
# Epoch 4/20
# 1407/1407 [==============================] - 8s 6ms/step - loss: 0.9574 - accuracy: 0.6678 - val_loss: 0.9986 - val_accuracy: 0.6522
# Epoch 5/20
# 1407/1407 [==============================] - 8s 6ms/step - loss: 0.8915 - accuracy: 0.6896 - val_loss: 0.9332 - val_accuracy: 0.6730
# Epoch 6/20
# 1407/1407 [==============================] - 8s 6ms/step - loss: 0.8399 - accuracy: 0.7091 - val_loss: 0.9435 - val_accuracy: 0.6728
# Epoch 7/20
# 1407/1407 [==============================] - 8s 6ms/step - loss: 0.7924 - accuracy: 0.7253 - val_loss: 0.9009 - val_accuracy: 0.6900
# Epoch 8/20
# 1407/1407 [==============================] - 8s 6ms/step - loss: 0.7512 - accuracy: 0.7387 - val_loss: 0.9120 - val_accuracy: 0.6894
# Epoch 9/20
# 1407/1407 [==============================] - 8s 6ms/step - loss: 0.7163 - accuracy: 0.7510 - val_loss: 0.9105 - val_accuracy: 0.6924
# Epoch 10/20
# 1407/1407 [==============================] - 9s 6ms/step - loss: 0.6844 - accuracy: 0.7603 - val_loss: 0.9386 - val_accuracy: 0.6884

# %%
# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
#plt.xlim([0,NUM_EPOCHS])
plt.ylim([0.4,1.0])
plt.show()

# %% [markdown]
# ## Evaluate Model

# %%
model.evaluate(test_images, test_labels)
# Out:
# 313/313 [==============================] - 1s 4ms/step - loss: 0.9625 - accuracy: 0.6843
# [0.9624667167663574, 0.6843000054359436]

# %% [markdown]
# **Accuracy**
# - Train: 85% - 90%;
# - Validation: 68%-70%
# - Test: 66%-68%

# %%
predictions = np.argmax(model.predict(test_images), axis=-1)
predictions.shape
# Out:
# (10000,)

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
print(classification_report(test_labels, predictions, target_names=class_names))
# Out:
#               precision    recall  f1-score   support
#
#     airplane       0.85      0.61      0.71      1000
#   automobile       0.85      0.76      0.80      1000
#         bird       0.62      0.55      0.58      1000
#          cat       0.53      0.43      0.48      1000
#         deer       0.60      0.64      0.62      1000
#          dog       0.51      0.73      0.60      1000
#         frog       0.75      0.80      0.77      1000
#        horse       0.73      0.72      0.73      1000
#         ship       0.79      0.80      0.79      1000
#        truck       0.73      0.80      0.76      1000
#
#     accuracy                           0.68     10000
#    macro avg       0.69      0.68      0.68     10000
# weighted avg       0.69      0.68      0.68     10000

# %%
confusion_matrix(test_labels,predictions)
# Out:
# array([[607,  27,  79,  30,  44,  16,  13,  27,  98,  59],
#        [  7, 758,  13,  11,   7,  14,   9,   7,  27, 147],
#        [ 28,   4, 547,  50, 114, 116,  64,  47,  16,  14],
#        [ 11,   8,  66, 433,  74, 287,  72,  27,  11,  11],
#        [  5,   2,  61,  58, 643,  68,  61,  82,  16,   4],
#        [  8,   3,  38, 107,  36, 735,  23,  37,   5,   8],
#        [  2,   1,  33,  50,  51,  49, 798,   7,   5,   4],
#        [  3,   3,  24,  34,  71, 120,  10, 722,   5,   8],
#        [ 32,  34,  22,  29,  14,  16,   6,   4, 797,  46],
#        [ 13,  55,   6,  20,  16,  27,   7,  25,  28, 803]])

# %%
class_names
# Out:
# ['airplane',
#  'automobile',
#  'bird',
#  'cat',
#  'deer',
#  'dog',
#  'frog',
#  'horse',
#  'ship',
#  'truck']

# %%
import seaborn as sns
plt.figure(figsize=(15,8))
sns.heatmap(confusion_matrix(test_labels,predictions), cmap='Blues', annot=True, fmt='g');

# %% [markdown]
# ## Testing Model (Predicting)

# %%
plt.imshow(test_images[15]);

# %%
test_labels[15][0]
# Out:
# 8

# %%
class_names[8]
# Out:
# 'ship'

# %%
test_images[15].shape
# Out:
# (32, 32, 3)

# %% [markdown]
# The input Tensor shape should be: (num_images, width, height, color_channels)

# %%
my_image = test_images[15]
my_image = my_image.reshape(1,32,32,3)
my_image.shape
# Out:
# (1, 32, 32, 3)

# %%
img_pred = np.argmax(model.predict(my_image))
class_names[img_pred]
# Out:
# 'frog'

# %%
img_pred
# Out:
# 6

# %%
pred_prob = model.predict(my_image)[0][img_pred]
pred_prob
# Out:
# 0.9583547

# %%
def img_pred(img, size=4):
    label = test_labels[img][0]
    my_image = test_images[img]
    plt.figure(figsize=(size,size))
    plt.imshow(my_image)
    my_image = my_image.reshape(1,32,32,3)
    img_pred = np.argmax(model.predict(my_image))
    pred_label = class_names[img_pred]
    pred_prob = model.predict(my_image)[0][img_pred]
    print(" Label {} <=> Pred: {} with prob {:.2}".format(
        class_names[label],
        pred_label,
        pred_prob))
    plt.grid(False)
    plt.axis('off')
    plt.show()

# %%
img_pred(0)
# Out:
#  Label cat <=> Pred: cat with prob 0.77

# %%
for i in range (10):
  img_pred(i)
# Out:
#  Label cat <=> Pred: cat with prob 0.77
#  Label ship <=> Pred: ship with prob 0.66
#  Label ship <=> Pred: truck with prob 0.45
#  Label airplane <=> Pred: airplane with prob 0.77
#  Label frog <=> Pred: frog with prob 0.45
#  Label frog <=> Pred: frog with prob 0.99
#  Label automobile <=> Pred: automobile with prob 0.86
#  Label frog <=> Pred: frog with prob 0.67
#  Label cat <=> Pred: cat with prob 0.71
#  Label automobile <=> Pred: automobile with prob 0.96

# %% [markdown]
# ## Saving the model

# %%
# !pwd # Linux command, shows where we are in CoLab's folders
# Out:
# /content

# %%
model.save('cifar_10_model')
# Out:
# INFO:tensorflow:Assets written to: cifar_10_model/assets

# %% [markdown]
# Use [Netron](https://netron.app) to visualize the model, hyperparameters, tensor shapes, etc. Netron is a viewer for neural network, deep learning and machine learning models (See [GitHub](https://github.com/lutzroeder/netron) for instructions about instalation in your desktop).

# %% [markdown]
# # Converting to TensorFlow Lite

# %% [markdown]
# You can convert the TF trained model using:  `TFLiteConverter.from_keras_model(model)`

# %%
converter = tf.lite.TFLiteConverter.from_keras_model(model)

# %% [markdown]
# Alternativally, is possible to convert the model from a saved model: `tf.lite.TFLiteConverter.from_saved_model(model_cifar10)` or from a Keras saved model: `tf.lite.TFLiteConverter.from_keras_model(model_cifar10.h5)`

# %%
# model_path = '/content/cifar_10_model'
# model_cifar10 = tf.keras.models.load_model(model_path)
# converter = tf.lite.TFLiteConverter.from_saved_model(model_cifar10)
# converter = tf.lite.TFLiteConverter.from_keras_model(model_cifar10)

# %%
tflite_model = converter.convert()
# Out:
# INFO:tensorflow:Assets written to: /tmp/tmprqr8kgp4/assets

# %%
# Save .tflite model
open("/content/cifar10.tflite","wb").write(tflite_model)
# Out:
# 673324

# %% [markdown]
# ## Dynamic range quantization
# The simplest form of post-training quantization statically quantizes only the weights from floating point to integer, which has 8-bits of precision:

# %%
converter = tf.lite.TFLiteConverter.from_keras_model(model)
converter.optimizations = [tf.lite.Optimize.DEFAULT]
tflite_quant_model = converter.convert()
# Out:
# INFO:tensorflow:Assets written to: /tmp/tmpyyiq46sj/assets
# INFO:tensorflow:Assets written to: /tmp/tmpyyiq46sj/assets

# %%
# Save .tflite model
open("/content/cifar10_quant.tflite","wb").write(tflite_quant_model)
# Out:
# 177232

# %% [markdown]
# Use [Netron](https://netron.app) to visualize the quantized model. Pay attention that now the weights are int8.

# %% [markdown]
# ## Uploading a saved TF model for convertion

# %% [markdown]
# If you'd like to upload your previous saved model in order to avoid re-train it:
#
# 1.   On the left of the UI click on the folder icon and go to sub-folder "content"
# 2.   Click on the three dots to the right of folder `content` file and select upload

# %%
model_path = '/content/cifar_10_model.h5'
model_cifar10 = tf.keras.models.load_model(model_path)
converter = tf.lite.TFLiteConverter.from_keras_model(model_cifar10)

# %%
converter.optimizations = [tf.lite.Optimize.DEFAULT]
tflite_quant_model = converter.convert()
# Out:
# INFO:tensorflow:Assets written to: /tmp/tmpxr5tzuy1/assets
# INFO:tensorflow:Assets written to: /tmp/tmpxr5tzuy1/assets

# %%
# Save .tflite model
tflite_model_size = open("/content/cifar10_quant_model.tflite","wb").write(tflite_quant_model)
print("Quantized model (DEFAULT) is {:,} bytes".format(tflite_model_size))
# Out:
# Quantized model (DEFAULT) is 177,232 bytes

# %% [markdown]
# ## Testing TFLite Model

# %%
interpreter = tf.lite.Interpreter("/content/cifar10_quant_model.tflite")

# %%
interpreter.allocate_tensors()
input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()

# %%
input_details
# Out:
# [{'dtype': numpy.float32,
#   'index': 0,
#   'name': 'conv2d_input',
#   'quantization': (0.0, 0),
#   'quantization_parameters': {'quantized_dimension': 0,
#    'scales': array([], dtype=float32),
#    'zero_points': array([], dtype=int32)},
#   'shape': array([ 1, 32, 32,  3], dtype=int32),
#   'shape_signature': array([-1, 32, 32,  3], dtype=int32),
#   'sparsity_parameters': {}}]

# %%
output_details
# Out:
# [{'dtype': numpy.float32,
#   'index': 17,
#   'name': 'Identity',
#   'quantization': (0.0, 0),
#   'quantization_parameters': {'quantized_dimension': 0,
#    'scales': array([], dtype=float32),
#    'zero_points': array([], dtype=int32)},
#   'shape': array([ 1, 10], dtype=int32),
#   'shape_signature': array([-1, 10], dtype=int32),
#   'sparsity_parameters': {}}]

# %%
def set_input_tensor(interpreter, image):
    tensor_index = interpreter.get_input_details()[0]['index']
    input_tensor = interpreter.tensor(tensor_index)()[0]
    input_tensor[:, :] = image

# %%
image = test_images[0]
plt.imshow(image);

# %%
set_input_tensor(interpreter, image)
interpreter.invoke()
output_details = interpreter.get_output_details()[0]

# %%
interpreter.get_tensor(output_details['index'])
# Out:
# array([[1.7630339e-03, 5.6266632e-05, 3.1530831e-04, 9.3056065e-01,
#         8.8554447e-07, 4.1046296e-03, 3.9717399e-02, 4.3506748e-08,
#         2.3398938e-02, 8.2843471e-05]], dtype=float32)

# %%
np.squeeze(interpreter.get_tensor(output_details['index']))
# Out:
# array([1.7630339e-03, 5.6266632e-05, 3.1530831e-04, 9.3056065e-01,
#        8.8554447e-07, 4.1046296e-03, 3.9717399e-02, 4.3506748e-08,
#        2.3398938e-02, 8.2843471e-05], dtype=float32)

# %%
output = np.squeeze(interpreter.get_tensor(output_details['index']))
output
# Out:
# array([1.7630339e-03, 5.6266632e-05, 3.1530831e-04, 9.3056065e-01,
#        8.8554447e-07, 4.1046296e-03, 3.9717399e-02, 4.3506748e-08,
#        2.3398938e-02, 8.2843471e-05], dtype=float32)

# %%
img_pred = np.argmax(output)
class_names[img_pred]
# Out:
# 'cat'

# %%
img_pred
# Out:
# 3

# %%
output[img_pred]
# Out:
# 0.93056065

# %%
def classify_image(image):
    set_input_tensor(interpreter, image)
    interpreter.invoke()
    output_details = interpreter.get_output_details()[0]
    output = np.squeeze(interpreter.get_tensor(output_details['index']))
    img_pred = np.argmax(output)
    pred_label = class_names[img_pred]
    pred_prob = output[img_pred]
    plt.imshow(image)
    print(" Pred: {} with prob {:.2}".format(
        pred_label,
        pred_prob))
    plt.grid(False)
    plt.axis('off')
    plt.show()

# %%
classify_image(test_images[0])
# Out:
#  Pred: cat with prob 0.93

# %%
for i in range (10):
  classify_image(test_images[i])
# Out:
#  Pred: cat with prob 0.93
#  Pred: ship with prob 0.99
#  Pred: automobile with prob 0.91
#  Pred: airplane with prob 1.0
#  Pred: deer with prob 0.82
#  Pred: frog with prob 0.99
#  Pred: automobile with prob 0.99
#  Pred: bird with prob 0.54
#  Pred: cat with prob 0.71
#  Pred: automobile with prob 1.0

# %% [markdown]
# # TensorFlow Lite Micro

# %%
import tensorflow as tf

# %%
model_path = '/content/cifar_10_model.h5'
model_cifar10 = tf.keras.models.load_model(model_path)
converter = tf.lite.TFLiteConverter.from_keras_model(model_cifar10)

# %%
converter.optimizations = [tf.lite.Optimize.DEFAULT]
tflite_quant_model = converter.convert()
# Out:
# INFO:tensorflow:Assets written to: /tmp/tmpbuw3hft9/assets

# %%
# Save .tflite model
tflite_model_size = open("/content/cifar10_quant_model.tflite","wb").write(tflite_quant_model)
print("Quantized model (DEFAULT) is {:,} bytes".format(tflite_model_size))
# Out:
# Quantized model (DEFAULT) is 177,232 bytes

# %% [markdown]
# ### Generate a TensorFlow Lite for Microcontrollers Model
# To convert the TensorFlow Lite quantized model into a C source file that can be loaded by TensorFlow Lite for Microcontrollers on MCUs, we simply need to use the ```xxd``` tool to convert the ```.tflite``` file into a ```.cc``` file.

# %% [markdown]
# **Convert to a C array**

# %% [markdown]
# First install xxd

# %%
# !apt-get update && apt-get -qq install xxd
# Out:
# 0% [Working]
#
# Get:1 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
#
# 0% [Connecting to archive.ubuntu.com (91.189.88.152)] [1 InRelease 14.2 kB/88.7
#
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease [3,626 B]
# Ign:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Ign:4 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Get:5 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease [15.9 kB]
# Get:6 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release [696 B]
# Hit:7 http://archive.ubuntu.com/ubuntu bionic InRelease
# Hit:8 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Get:9 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release.gpg [836 B]
# Get:10 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Get:11 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ Packages [69.5 kB]
# Hit:12 http://ppa.launchpad.net/cran/libgit2/ubuntu bionic InRelease
# Get:13 http://security.ubuntu.com/ubuntu bionic-security/main amd64 Packages [2,398 kB]
# Get:14 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic InRelease [15.9 kB]
# Get:15 http://archive.ubuntu.com/ubuntu bionic-backports InRelease [74.6 kB]
# Get:16 http://security.ubuntu.com/ubuntu bionic-security/restricted amd64 Packages [632 kB]
# Get:17 http://security.ubuntu.com/ubuntu bionic-security/universe amd64 Packages [1,434 kB]
# Hit:18 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease
# Get:20 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Packages [754 kB]
# Get:21 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main Sources [1,810 kB]
# Get:22 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 Packages [2,835 kB]
# Get:23 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main amd64 Packages [926 kB]
# Get:24 http://archive.ubuntu.com/ubuntu bionic-updates/restricted amd64 Packages [665 kB]
# Get:25 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 Packages [2,213 kB]
# Get:26 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic/main amd64 Packages [45.3 kB]
# Fetched 14.1 MB in 4s (3,768 kB/s)
# Reading package lists... Done

# %% [markdown]
# Now, convert and save the .cc converted model

# %%
MODEL_TFLITE = 'cifar10_quant_model.tflite'
MODEL_TFLITE_MICRO = 'cifar10_quant_model.cc'
# !xxd -i {MODEL_TFLITE} > {MODEL_TFLITE_MICRO}
REPLACE_TEXT = MODEL_TFLITE.replace('/', '_').replace('.', '_')
# !sed -i 's/'{REPLACE_TEXT}'/g_model/g' {MODEL_TFLITE_MICRO}

# %% [markdown]
# If you'd like to download your model for safekeeping:
# 1. On the left of the UI click on the folder icon
# 2. Click on the three dots to the right of the ```cifar10_quant_model.cc``` file and select download

# %%
# !cat {MODEL_TFLITE_MICRO}
# Out:
# Streaming output truncated to the last 5000 lines.
#   0x02, 0x15, 0x01, 0xd1, 0x02, 0xe9, 0xee, 0x07, 0x2d, 0x18, 0xfe, 0x01,
#   0x1c, 0xfa, 0x03, 0xf6, 0x0c, 0xf2, 0xed, 0xed, 0x06, 0xf2, 0xfa, 0xda,
#   0x0f, 0xf1, 0x06, 0x0e, 0xee, 0xf8, 0x01, 0x0e, 0x07, 0x03, 0xf7, 0x30,
#   0xf7, 0xfa, 0xf7, 0x0a, 0x09, 0xff, 0x12, 0x02, 0xfb, 0x01, 0x14, 0xf8,
#   0x07, 0xd8, 0xfd, 0x0b, 0x01, 0x1e, 0xc3, 0x10, 0x20, 0x2c, 0x0f, 0xf1,
#   0x04, 0x10, 0x05, 0x2a, 0xd9, 0xf3, 0x0a, 0x00, 0xfd, 0xe0, 0xda, 0x1a,
#   0xfb, 0xea, 0xfd, 0xf5, 0x0a, 0x00, 0xff, 0xe8, 0xf3, 0xe4, 0x03, 0x15,
#   0x04, 0x0d, 0xff, 0xdb, 0xd9, 0x06, 0x0b, 0xda, 0xdb, 0xf9, 0x00, 0x03,
#   0x0b, 0x08, 0x03, 0x03, 0x25, 0xf9, 0xd5, 0x02, 0x0e, 0x0a, 0xf1, 0xf7,
#   0x09, 0x0d, 0x0c, 0xb6, 0x12, 0x08, 0x02, 0xf8, 0x04, 0x02, 0x17, 0x10,
#   0x0e, 0xdf, 0x01, 0xd0, 0xff, 0x00, 0xfd, 0x0f, 0x1c, 0x02, 0x17, 0x0a,
#   0x05, 0xf0, 0xfb, 0xed, 0x21, 0xfe, 0xfd, 0xec, 0xdf, 0x04, 0x03, 0xf9,
#   0x1a, 0xb7, 0x01, 0xdf, 0x12, 0x29, 0x03, 0xe6, 0xee, 0xf5, 0x2b, 0xfd,
#   0x19, 0xf5, 0xfe, 0x02, 0x03, 0x0e, 0xd1, 0xe1, 0x0f, 0x0d, 0x08, 0x08,
#   0x03, 0x00, 0xec, 0x0a, 0xe5, 0xf0, 0xe4, 0x18, 0x0a, 0xeb, 0xff, 0x1a,
#   0xfb, 0xf2, 0xda, 0xec, 0x17, 0x03, 0xff, 0xf6, 0x04, 0x1b, 0xf9, 0xf9,
#   0xd6, 0xfe, 0x19, 0xc6, 0x01, 0xfc, 0xfd, 0xda, 0x2d, 0x10, 0x01, 0x0a,
#   0xf5, 0xfa, 0xf7, 0x2e, 0xf1, 0xfb, 0xef, 0xc6, 0xee, 0xef, 0xfd, 0xea,
#   0x18, 0xfe, 0xda, 0x32, 0x0b, 0x10, 0x06, 0xee, 0xf7, 0x1b, 0xf5, 0x04,
#   0xe3, 0xf2, 0xfc, 0xea, 0xf1, 0x04, 0xdc, 0x00, 0xe4, 0xda, 0xe7, 0xe5,
#   0x23, 0x20, 0xfd, 0xe5, 0xfe, 0x15, 0xf6, 0xe9, 0xe2, 0xf9, 0xef, 0xe7,
#   0x00, 0xe7, 0xfd, 0x1c, 0xec, 0xf4, 0xf1, 0xe9, 0x05, 0xd4, 0xff, 0xdf,
#   0x1f, 0x0e, 0xfc, 0x16, 0x08, 0xff, 0xfe, 0x22, 0xf5, 0x04, 0x10, 0xb6,
#   0xfa, 0xfc, 0xff, 0x02, 0x0c, 0xf1, 0xe7, 0x2b, 0x2b, 0x27, 0x01, 0x00,
#   0xf2, 0x24, 0x0a, 0xf7, 0x12, 0xf9, 0xc0, 0x08, 0xfd, 0x05, 0xfa, 0xfe,
#   0xf8, 0xea, 0xed, 0xf1, 0xf5, 0x17, 0xfd, 0x0b, 0x03, 0x0f, 0x18, 0x07,
#   0xe9, 0x1a, 0xd6, 0xd0, 0x07, 0x12, 0xfb, 0x00, 0xc4, 0x05, 0xfc, 0xab,
#   0xfc, 0xd6, 0xee, 0x1b, 0xf4, 0x11, 0xfd, 0x03, 0x20, 0xf8, 0x01, 0x0c,
#   0x11, 0xab, 0xda, 0xda, 0xf8, 0xf3, 0xfc, 0xfe, 0x26, 0x0f, 0xeb, 0x1b,
#   0x33, 0x29, 0xfd, 0x18, 0x1c, 0x0e, 0xfb, 0xf7, 0x0d, 0x00, 0xbc, 0x06,
#   0xfd, 0x06, 0xf4, 0xe9, 0xef, 0xfa, 0x0c, 0xe7, 0x06, 0xf4, 0xfb, 0xd1,
#   0x02, 0xfc, 0xe7, 0x09, 0x21, 0xd2, 0xda, 0xe5, 0x01, 0x1d, 0xfc, 0xfd,
#   0xed, 0x19, 0x10, 0xd2, 0x05, 0xd5, 0xf1, 0x17, 0x3e, 0xf5, 0x02, 0xff,
#   0xfc, 0xf8, 0x03, 0xff, 0xf3, 0xcb, 0xee, 0xf0, 0x12, 0xf6, 0x00, 0xeb,
#   0x08, 0xdf, 0xd3, 0x1b, 0xef, 0x1f, 0x01, 0x28, 0x15, 0xf0, 0xf2, 0x12,
#   0xfc, 0x10, 0xd9, 0x1c, 0x09, 0x07, 0xf9, 0xed, 0xcd, 0xf3, 0x09, 0xe1,
#   0x18, 0xf0, 0x03, 0x1f, 0x05, 0x02, 0xef, 0x20, 0xe6, 0x06, 0x10, 0xf9,
#   0x07, 0x0d, 0x05, 0xf4, 0xd2, 0x0b, 0x09, 0x0d, 0x06, 0xcc, 0x08, 0xfe,
#   0x0e, 0x08, 0xfe, 0xf9, 0x0f, 0x02, 0x06, 0xee, 0x0c, 0xc6, 0xd0, 0x07,
#   0x0e, 0xda, 0xfe, 0x0d, 0xf0, 0xe7, 0x30, 0x18, 0xf5, 0x20, 0xfc, 0xfd,
#   0x0c, 0x0c, 0x05, 0xea, 0xec, 0xe7, 0x11, 0x16, 0x0a, 0xfc, 0x13, 0x07,
#   0xf4, 0xea, 0x15, 0xb7, 0x1c, 0xfe, 0xfd, 0x01, 0xfe, 0xe9, 0x02, 0x20,
#   0xc2, 0x1d, 0x26, 0x05, 0x07, 0x18, 0x03, 0x11, 0xe6, 0x1c, 0x0d, 0x1e,
#   0x03, 0xf1, 0x05, 0x0d, 0x22, 0xef, 0xfb, 0xfb, 0xe7, 0xf9, 0x04, 0xf7,
#   0xea, 0xd8, 0x0a, 0xe7, 0xe2, 0xf3, 0xfb, 0x0b, 0xf9, 0xfe, 0xe8, 0x14,
#   0xed, 0xf5, 0xfb, 0xf1, 0x0c, 0xfd, 0xf8, 0xdc, 0x0b, 0x1d, 0xf4, 0xf8,
#   0xd3, 0x06, 0xd9, 0x0b, 0xe3, 0xd5, 0xf6, 0xe1, 0xdd, 0xde, 0xff, 0xdb,
#   0xff, 0xf3, 0xfa, 0x04, 0x21, 0x01, 0xf1, 0xee, 0xfd, 0x2d, 0x05, 0x1e,
#   0xc8, 0xe0, 0x07, 0x06, 0xfd, 0xcd, 0x08, 0x05, 0x19, 0xfa, 0x06, 0x09,
#   0x01, 0xff, 0x06, 0xf1, 0x0d, 0xf1, 0xda, 0xe4, 0xdd, 0xeb, 0x06, 0xf8,
#   0x21, 0xfb, 0x2c, 0x08, 0x15, 0x12, 0x02, 0xf7, 0xfc, 0xf9, 0xe9, 0x21,
#   0x0d, 0x10, 0xe3, 0xf4, 0xc1, 0x02, 0x0b, 0xfe, 0xcb, 0x07, 0xf9, 0xf9,
#   0xf9, 0x05, 0xff, 0x09, 0x01, 0x06, 0xe9, 0x01, 0x0b, 0xf4, 0xe4, 0xdf,
#   0xff, 0x28, 0xfa, 0x07, 0x1d, 0xf4, 0xec, 0xfe, 0xff, 0xea, 0xd8, 0xe6,
#   0xe8, 0xf7, 0x05, 0x00, 0xf8, 0xfb, 0x00, 0x04, 0x0f, 0x00, 0xc8, 0xae,
#   0xfa, 0x03, 0xff, 0xc9, 0x27, 0xd7, 0xfb, 0x10, 0x25, 0x27, 0x05, 0xe4,
#   0x04, 0xf4, 0xed, 0x02, 0x14, 0xeb, 0xf7, 0xfe, 0xed, 0xfa, 0x03, 0xee,
#   0xdd, 0xf0, 0xd6, 0x22, 0x0f, 0x0c, 0xfc, 0xe9, 0x01, 0x04, 0x13, 0xfe,
#   0x0b, 0xdc, 0xe6, 0xc6, 0x09, 0xf6, 0x00, 0x06, 0xd3, 0xe5, 0xfd, 0xbd,
#   0x05, 0x9b, 0xe4, 0xf5, 0xff, 0xfb, 0xfd, 0xf8, 0xf4, 0x00, 0x01, 0xf9,
#   0x08, 0xe7, 0xf6, 0xea, 0xf3, 0xd1, 0x00, 0x07, 0x0b, 0xcd, 0x1b, 0x32,
#   0x1f, 0x2b, 0x01, 0xf3, 0x11, 0xf2, 0x04, 0x07, 0xff, 0x10, 0xce, 0x21,
#   0x11, 0xf2, 0x12, 0xd1, 0xb0, 0xec, 0x02, 0x05, 0x29, 0x04, 0x04, 0xe8,
#   0x03, 0x35, 0x2f, 0x00, 0x2e, 0x06, 0x0b, 0xe2, 0x0b, 0x17, 0x00, 0x22,
#   0xf8, 0xea, 0x05, 0xf1, 0x01, 0xd1, 0xd9, 0xfa, 0x15, 0xf5, 0x00, 0xf5,
#   0x0c, 0xfd, 0xfd, 0x24, 0xc5, 0xe9, 0x0f, 0xe8, 0xfd, 0x19, 0xfd, 0xfa,
#   0x1b, 0xf7, 0x12, 0x26, 0x15, 0x2b, 0x03, 0x35, 0x0f, 0x0d, 0x20, 0xe4,
#   0xf0, 0xe9, 0xdc, 0x0a, 0x12, 0xf4, 0x16, 0xec, 0x00, 0xf1, 0x1a, 0xd5,
#   0x1b, 0x0c, 0x02, 0xfb, 0xfd, 0xf5, 0xe2, 0xff, 0x1d, 0x04, 0x13, 0x02,
#   0x04, 0xe1, 0xfa, 0x12, 0xf2, 0xed, 0xf9, 0x12, 0x04, 0xf6, 0xf9, 0x00,
#   0x1f, 0x1d, 0xfb, 0xfb, 0x2b, 0x03, 0xfc, 0x25, 0xf6, 0xec, 0xd3, 0x0a,
#   0xe9, 0x2e, 0x03, 0x05, 0x39, 0xc7, 0x1d, 0x3c, 0xff, 0x30, 0x04, 0x11,
#   0x1e, 0x0a, 0xe1, 0x0c, 0x0a, 0xfc, 0xd5, 0xec, 0x15, 0xf7, 0x1a, 0x0e,
#   0xf3, 0xce, 0xf3, 0x30, 0x0a, 0x14, 0x05, 0xf7, 0xfc, 0xf3, 0x28, 0x1c,
#   0x04, 0x00, 0x03, 0xef, 0x03, 0xef, 0xff, 0x10, 0xc9, 0x07, 0xf8, 0x04,
#   0xfd, 0xf6, 0xe2, 0xe9, 0x13, 0x0c, 0x06, 0xfa, 0xff, 0xfc, 0x02, 0x23,
#   0xeb, 0xf8, 0x0a, 0xfc, 0xf9, 0x00, 0xfa, 0x0f, 0x07, 0x30, 0x11, 0xf1,
#   0x10, 0xf1, 0xfe, 0xf3, 0x10, 0x01, 0xef, 0xf7, 0x18, 0x13, 0xb5, 0x05,
#   0xe7, 0xff, 0x22, 0x0a, 0x1b, 0xc0, 0x0b, 0x1c, 0x03, 0xf0, 0xff, 0xf3,
#   0xff, 0xbb, 0xdc, 0x09, 0xfa, 0xff, 0xdc, 0xec, 0x06, 0x12, 0xfd, 0x00,
#   0xc1, 0x07, 0x07, 0xec, 0x02, 0xff, 0x0a, 0xea, 0x25, 0xfe, 0xff, 0xf8,
#   0xf7, 0x07, 0xfb, 0x0d, 0x04, 0xf7, 0xfc, 0xe1, 0xd3, 0xfa, 0x04, 0xe8,
#   0x2a, 0x02, 0x34, 0xff, 0x0d, 0x00, 0xfb, 0xed, 0x08, 0xf3, 0xe1, 0x00,
#   0xd9, 0x22, 0xd5, 0xf9, 0xe8, 0x02, 0x1b, 0x1e, 0xdd, 0xde, 0x12, 0x11,
#   0xf8, 0xdf, 0xfc, 0x13, 0x03, 0xe2, 0x09, 0xfa, 0xc5, 0xc6, 0xeb, 0xdf,
#   0x0b, 0xff, 0x00, 0xf9, 0xfc, 0xf9, 0xda, 0x08, 0xfd, 0xc8, 0xfa, 0xff,
#   0x0d, 0xfe, 0xfb, 0xe4, 0xfd, 0xf9, 0x04, 0xf3, 0xdb, 0x15, 0xd1, 0xd3,
#   0xe3, 0x08, 0x01, 0xf9, 0x08, 0xfb, 0x40, 0x15, 0x08, 0x37, 0x01, 0xfc,
#   0x12, 0x20, 0xe5, 0xf6, 0xd7, 0x12, 0xe2, 0x13, 0xed, 0x0b, 0x20, 0xf6,
#   0xd9, 0xda, 0x45, 0x08, 0x0b, 0xd7, 0xfc, 0x42, 0x0a, 0xe5, 0x1d, 0xf0,
#   0x01, 0xea, 0xfb, 0x0c, 0x0c, 0xe5, 0x01, 0x1a, 0xb4, 0xf9, 0xc5, 0x16,
#   0xfc, 0xcb, 0x06, 0x0f, 0xf9, 0x1f, 0xff, 0xed, 0x25, 0x05, 0x05, 0xe6,
#   0xf2, 0xe4, 0x11, 0xea, 0x02, 0xe2, 0x04, 0xea, 0x1c, 0xde, 0x17, 0x21,
#   0x05, 0x13, 0x04, 0xf7, 0x0b, 0xf8, 0x14, 0xec, 0xd2, 0xec, 0x03, 0x0c,
#   0xe9, 0x05, 0x05, 0xe1, 0xd9, 0x18, 0x12, 0x0f, 0x01, 0xf9, 0xfd, 0xff,
#   0xff, 0x3c, 0xd9, 0x06, 0x16, 0xfc, 0xe3, 0xf4, 0x0c, 0xca, 0xfd, 0x27,
#   0xdf, 0xf3, 0x05, 0x22, 0x03, 0xb8, 0xf5, 0x02, 0x25, 0x0f, 0x03, 0xf9,
#   0x17, 0x08, 0x06, 0x01, 0xf9, 0xe0, 0x15, 0xde, 0x0e, 0xff, 0xfd, 0xc7,
#   0x25, 0xda, 0x42, 0x44, 0x15, 0x2c, 0x03, 0x0b, 0x0e, 0x0e, 0x0d, 0xd1,
#   0xf1, 0xe2, 0xd5, 0xf4, 0xed, 0xf7, 0xfd, 0x11, 0xb1, 0xc2, 0x09, 0xf6,
#   0xf9, 0x14, 0x02, 0xe5, 0xfd, 0x0a, 0x13, 0x25, 0x26, 0x04, 0x0d, 0x0a,
#   0x0b, 0xbd, 0x00, 0xfd, 0x0b, 0xfb, 0xc8, 0xfb, 0xfc, 0xe0, 0xfd, 0x0a,
#   0x0e, 0xfe, 0xff, 0x0f, 0x20, 0x02, 0xfe, 0x12, 0xe3, 0xf9, 0x07, 0x33,
#   0xef, 0x22, 0xff, 0xfb, 0x0f, 0xf8, 0x15, 0x2f, 0x39, 0x2e, 0x01, 0xe7,
#   0x19, 0x0e, 0x03, 0xe4, 0xfd, 0xf0, 0xd9, 0x0a, 0x0f, 0xfe, 0x07, 0x0a,
#   0xfd, 0x12, 0x1c, 0x18, 0x19, 0x18, 0x05, 0x08, 0xfe, 0x0e, 0xfa, 0x25,
#   0x29, 0xf2, 0x1b, 0xfa, 0x0b, 0xfd, 0x02, 0x25, 0x16, 0xc3, 0xe2, 0xfa,
#   0xfe, 0x3c, 0x03, 0xd8, 0x0c, 0xff, 0xfb, 0xfc, 0x02, 0xfc, 0xfb, 0x08,
#   0xe9, 0xfd, 0x04, 0xfc, 0xf1, 0xd6, 0xfe, 0x13, 0x11, 0x16, 0x16, 0xe4,
#   0x23, 0xe6, 0x04, 0xdd, 0xf0, 0x18, 0xe0, 0x11, 0xe2, 0x02, 0xf0, 0x0e,
#   0x16, 0x07, 0xf8, 0xfb, 0x12, 0x2b, 0xf1, 0x2d, 0xe5, 0x07, 0x01, 0xee,
#   0x04, 0x20, 0xd1, 0x0a, 0x12, 0x1f, 0x01, 0xf6, 0x01, 0x1d, 0x01, 0xdc,
#   0xe4, 0xff, 0x12, 0x21, 0xfc, 0xf8, 0x13, 0x01, 0xc8, 0x12, 0x05, 0x00,
#   0xde, 0xfe, 0x00, 0x10, 0x06, 0xe4, 0x1d, 0xef, 0x12, 0x2c, 0xff, 0x05,
#   0xf3, 0x0c, 0xf2, 0xff, 0x23, 0x06, 0xff, 0xe6, 0xdc, 0xfd, 0xf8, 0x0b,
#   0xfb, 0x1e, 0xcb, 0x0f, 0x1e, 0x0a, 0xf3, 0xf2, 0x0e, 0x0a, 0xe6, 0x1d,
#   0xe0, 0xf7, 0xfe, 0x26, 0x02, 0xf6, 0xed, 0xfb, 0x1a, 0xf5, 0xe5, 0xfe,
#   0x10, 0xdc, 0x01, 0x0b, 0xf1, 0xeb, 0xb8, 0x08, 0xfb, 0xf5, 0x10, 0x15,
#   0x22, 0x05, 0xfe, 0xe2, 0x11, 0x02, 0xfc, 0x21, 0xfe, 0xed, 0xe9, 0x00,
#   0x0e, 0x06, 0xff, 0x0b, 0x30, 0x1f, 0xf1, 0xf7, 0x06, 0xfe, 0xff, 0x0e,
#   0x1a, 0x05, 0x0c, 0xf3, 0xea, 0x0c, 0x1b, 0x04, 0x0c, 0x04, 0x06, 0x11,
#   0x39, 0xf1, 0x0f, 0x09, 0xd6, 0xd9, 0x04, 0x06, 0x03, 0xfe, 0x1c, 0x0b,
#   0x09, 0xf4, 0xee, 0x1a, 0x0e, 0xcb, 0x05, 0x0b, 0x12, 0x14, 0xf0, 0x0c,
#   0x01, 0xfa, 0x2d, 0x06, 0xf7, 0x04, 0x05, 0xd7, 0xcd, 0x04, 0xfb, 0x15,
#   0x06, 0xf9, 0x13, 0xed, 0xf1, 0xe2, 0xfd, 0xe4, 0x19, 0x06, 0xbf, 0x16,
#   0x0f, 0x0e, 0xff, 0x18, 0xe2, 0x0e, 0x11, 0xef, 0x14, 0xee, 0x14, 0x29,
#   0xf3, 0xfe, 0x05, 0x05, 0xff, 0xe5, 0x06, 0xed, 0x15, 0xf3, 0x00, 0x0a,
#   0xfd, 0x0d, 0xec, 0xd3, 0x1c, 0x04, 0x04, 0x38, 0x03, 0x0f, 0xff, 0x1e,
#   0x25, 0xe0, 0xf1, 0xeb, 0xfb, 0xca, 0x10, 0xed, 0xe9, 0x11, 0x04, 0x0f,
#   0x12, 0xf8, 0x01, 0x08, 0xf1, 0x2f, 0x13, 0xf1, 0xff, 0xe3, 0x00, 0xff,
#   0xed, 0xf6, 0x0f, 0x20, 0xfe, 0x12, 0xfc, 0x10, 0xf0, 0xfb, 0xfe, 0x02,
#   0xd4, 0xf1, 0x26, 0xf6, 0xef, 0xfd, 0xde, 0x10, 0xeb, 0x07, 0xe9, 0xf7,
#   0xd9, 0x06, 0xfb, 0x28, 0x04, 0x09, 0x23, 0xe4, 0x0a, 0x15, 0x0d, 0xf5,
#   0x06, 0xe1, 0xfe, 0xf6, 0x18, 0xef, 0xe9, 0xed, 0xfc, 0x21, 0x18, 0xee,
#   0xeb, 0xfb, 0xff, 0x19, 0x17, 0xfe, 0xfd, 0xf7, 0xe6, 0x0a, 0x0f, 0xfa,
#   0x1b, 0x20, 0xff, 0xf2, 0xf8, 0x07, 0xff, 0x15, 0x11, 0x09, 0x00, 0xff,
#   0xdd, 0xe0, 0xfa, 0xff, 0x24, 0x00, 0x33, 0xfb, 0x0c, 0xfc, 0xf4, 0x0a,
#   0x0d, 0x08, 0xfc, 0xf1, 0xe3, 0x21, 0xfe, 0x25, 0x05, 0x07, 0x15, 0x04,
#   0xfe, 0x16, 0x14, 0x0f, 0x01, 0x06, 0x03, 0x28, 0x14, 0xf9, 0x26, 0xec,
#   0x06, 0x1b, 0x01, 0xf3, 0xfc, 0x11, 0xfc, 0xfe, 0x0f, 0x00, 0x00, 0xf2,
#   0xf9, 0x04, 0xee, 0xfb, 0xfc, 0x30, 0x04, 0x0c, 0xeb, 0x20, 0xf2, 0xea,
#   0xe5, 0xec, 0x01, 0xf1, 0x18, 0x09, 0xf7, 0x03, 0x02, 0x05, 0xed, 0xea,
#   0x31, 0xfe, 0xef, 0xdd, 0x37, 0x0c, 0x1d, 0xfc, 0x11, 0xc7, 0x04, 0x24,
#   0xfa, 0xf7, 0xe7, 0xf7, 0xdf, 0xe6, 0xfc, 0x2e, 0x03, 0x0d, 0xfd, 0x19,
#   0x20, 0xe6, 0x1c, 0x27, 0xfe, 0xfc, 0x0b, 0x00, 0xe5, 0xec, 0xff, 0xe6,
#   0x1d, 0xfd, 0x01, 0x0f, 0xe0, 0x0b, 0x03, 0xe9, 0x08, 0x1d, 0x06, 0x1b,
#   0x0b, 0x19, 0xf8, 0x08, 0xf7, 0x1b, 0x02, 0xfb, 0xe9, 0x2d, 0x03, 0xfb,
#   0xfe, 0x06, 0xce, 0x03, 0x20, 0xfc, 0x04, 0xed, 0xfe, 0x21, 0xfc, 0x25,
#   0x04, 0x04, 0xfb, 0x1c, 0xfc, 0x05, 0x09, 0x0e, 0x35, 0x2a, 0xff, 0xed,
#   0x01, 0xe4, 0x05, 0x10, 0x06, 0xf2, 0x07, 0xfc, 0x06, 0x04, 0x03, 0xf6,
#   0x0a, 0xe3, 0xff, 0xf1, 0x0f, 0xfd, 0x01, 0x09, 0x09, 0x03, 0x03, 0x36,
#   0x05, 0x1e, 0x02, 0xfa, 0xf3, 0x02, 0x1a, 0x14, 0xef, 0x13, 0x03, 0x12,
#   0x0b, 0x0f, 0x1b, 0xb0, 0xfd, 0xfd, 0xcb, 0xf3, 0x20, 0x00, 0xfb, 0xd9,
#   0x02, 0xf3, 0xe1, 0xee, 0x21, 0x07, 0xfc, 0x0a, 0x05, 0xf1, 0x0f, 0xf7,
#   0x00, 0xed, 0xf0, 0x00, 0x09, 0xd3, 0x01, 0x1e, 0x08, 0x21, 0x0b, 0x1e,
#   0x02, 0x2d, 0xe4, 0x26, 0xf7, 0x0b, 0x00, 0xed, 0xc9, 0x04, 0xfe, 0x00,
#   0xf8, 0xe6, 0x06, 0x0a, 0xfa, 0xd9, 0x02, 0x0c, 0xf8, 0x15, 0xff, 0x2a,
#   0x0b, 0x20, 0x05, 0xfc, 0x01, 0xfd, 0x01, 0x03, 0x00, 0xcc, 0xd4, 0xe8,
#   0xf4, 0x04, 0x0a, 0x06, 0x26, 0xed, 0xd2, 0x16, 0xd3, 0x0d, 0x01, 0x2e,
#   0x03, 0xec, 0x18, 0xd6, 0x09, 0x11, 0x17, 0x0a, 0x0d, 0xf9, 0x02, 0x27,
#   0x15, 0x11, 0x12, 0xf7, 0xfe, 0x1e, 0xfb, 0xf7, 0x0b, 0x06, 0x08, 0xee,
#   0x09, 0x05, 0x05, 0x06, 0x07, 0xfc, 0xfd, 0xea, 0xf4, 0xe7, 0xfe, 0xe7,
#   0xef, 0x17, 0xd4, 0x13, 0x16, 0xf1, 0xfb, 0x05, 0xf9, 0xf9, 0x08, 0xf8,
#   0x07, 0xe3, 0x2b, 0xf3, 0xe4, 0x03, 0xd3, 0x22, 0x13, 0x03, 0xf8, 0xf7,
#   0x05, 0x25, 0x01, 0x2a, 0x02, 0x13, 0x2b, 0xe8, 0x24, 0x21, 0x04, 0x1f,
#   0x0c, 0xe5, 0xf9, 0x2f, 0x16, 0xda, 0x18, 0x09, 0x00, 0x2b, 0x14, 0xf9,
#   0x0d, 0xfc, 0x03, 0x0e, 0x03, 0x01, 0xff, 0x15, 0x2b, 0x23, 0xe7, 0xd6,
#   0xec, 0x0a, 0x00, 0xe3, 0x06, 0x18, 0x16, 0xd7, 0x0c, 0xc5, 0x05, 0x1b,
#   0xdd, 0x1e, 0xe1, 0x1b, 0xf2, 0xfd, 0x2a, 0x14, 0xc8, 0x0b, 0xc6, 0x0d,
#   0xfe, 0xe6, 0xf0, 0xfb, 0xed, 0x06, 0x00, 0x25, 0x04, 0x03, 0x16, 0xeb,
#   0xfb, 0x1c, 0xf8, 0x15, 0x08, 0xf9, 0xfa, 0x20, 0x0c, 0xbd, 0xf6, 0x01,
#   0xff, 0x24, 0xff, 0x16, 0xd1, 0xfc, 0x00, 0x1c, 0x0d, 0x04, 0xfe, 0x03,
#   0x01, 0x01, 0xff, 0xff, 0x04, 0x05, 0x05, 0x02, 0x00, 0xf9, 0xfc, 0x03,
#   0xfa, 0xfe, 0x02, 0xfd, 0x01, 0x06, 0xf9, 0xfb, 0x04, 0xfb, 0xfa, 0x03,
#   0xfe, 0xff, 0x01, 0xfb, 0x03, 0x03, 0x03, 0x04, 0xfc, 0xfa, 0x02, 0x03,
#   0xfa, 0x00, 0xfd, 0x00, 0x02, 0x05, 0xff, 0x04, 0x05, 0xfe, 0xfd, 0x03,
#   0xfd, 0x00, 0x05, 0x01, 0xfe, 0x03, 0xff, 0xf9, 0x04, 0x00, 0x02, 0xfa,
#   0x01, 0xfc, 0xff, 0x02, 0x05, 0x02, 0xff, 0x00, 0xf9, 0xfd, 0xff, 0x04,
#   0xf9, 0xfe, 0xfc, 0xfe, 0x04, 0xfc, 0x01, 0x00, 0xff, 0x02, 0xfd, 0x04,
#   0x02, 0xfc, 0xfe, 0xfa, 0x00, 0x02, 0x02, 0xfc, 0xfa, 0xf8, 0xfa, 0xfb,
#   0xff, 0xfb, 0x04, 0x00, 0x00, 0xfb, 0xff, 0x02, 0x01, 0xff, 0xfa, 0xfe,
#   0x02, 0x05, 0x00, 0x04, 0xfd, 0xf8, 0x01, 0x02, 0xfb, 0xfb, 0xfe, 0x04,
#   0xfa, 0x04, 0x00, 0x04, 0x02, 0xfd, 0xfd, 0xfa, 0xfd, 0xfe, 0xfe, 0x02,
#   0x00, 0x04, 0x03, 0xfb, 0xfb, 0xfe, 0xfe, 0xf8, 0x04, 0xfe, 0xfe, 0xfe,
#   0x03, 0xfa, 0xff, 0x02, 0x00, 0xfc, 0x00, 0xff, 0x02, 0xff, 0xfa, 0xfc,
#   0x02, 0x01, 0xfe, 0xfb, 0x01, 0xf9, 0xfe, 0xfb, 0x02, 0xf9, 0xfe, 0xf9,
#   0x05, 0x00, 0x00, 0x05, 0xfe, 0xfd, 0xff, 0xfd, 0x05, 0x05, 0xfe, 0x00,
#   0xfe, 0x02, 0x02, 0x01, 0x00, 0xfc, 0xfc, 0xfd, 0xfa, 0x01, 0xfd, 0x04,
#   0xf9, 0xff, 0xfc, 0xfd, 0xfb, 0xfb, 0xfd, 0xf8, 0x02, 0xf9, 0x00, 0xfc,
#   0xfb, 0x03, 0xfe, 0xff, 0xfd, 0xff, 0xfe, 0xf9, 0x01, 0x00, 0xfd, 0xfd,
#   0xfc, 0xfe, 0xf9, 0xfc, 0x05, 0xfe, 0x01, 0x03, 0xfe, 0x00, 0xfd, 0xfc,
#   0x06, 0xfb, 0xff, 0xfd, 0x00, 0xfb, 0xfc, 0x00, 0x05, 0xf9, 0xff, 0xff,
#   0xfa, 0x03, 0x05, 0x03, 0xfd, 0x03, 0xf8, 0x03, 0xff, 0xff, 0xff, 0xfc,
#   0x03, 0x04, 0xfd, 0x02, 0xfc, 0x01, 0xfb, 0xfb, 0x00, 0x05, 0x02, 0x00,
#   0x00, 0x01, 0xff, 0xfa, 0x03, 0x03, 0x05, 0xff, 0xfa, 0xfb, 0xfc, 0x01,
#   0xff, 0xfd, 0xfd, 0xf7, 0xfa, 0x00, 0xf9, 0xfc, 0xfe, 0xff, 0xfd, 0xff,
#   0x02, 0xfa, 0x05, 0xfd, 0x05, 0xfb, 0x00, 0x00, 0x03, 0xff, 0xff, 0x05,
#   0x05, 0x02, 0x02, 0x00, 0x01, 0xfb, 0x02, 0x05, 0xfd, 0xfe, 0xfc, 0xfe,
#   0x03, 0xff, 0x02, 0x05, 0xff, 0xff, 0x03, 0xff, 0x06, 0xfd, 0xff, 0xfe,
#   0x01, 0x04, 0xfb, 0x00, 0xfe, 0xfe, 0xfe, 0xfe, 0xfb, 0x02, 0x05, 0xff,
#   0xfe, 0x00, 0xfc, 0x04, 0xff, 0x03, 0x04, 0x01, 0xfc, 0x00, 0x00, 0x00,
#   0xff, 0xfc, 0xff, 0x00, 0x03, 0x03, 0xfc, 0xfd, 0xfd, 0xfe, 0x04, 0xfe,
#   0x05, 0xfa, 0xf7, 0x02, 0x01, 0xfc, 0x03, 0xfb, 0xff, 0x02, 0x00, 0x04,
#   0xfe, 0xfd, 0xfc, 0x01, 0xfc, 0x01, 0x05, 0x01, 0xf9, 0x01, 0xfa, 0x00,
#   0xfc, 0xff, 0x00, 0xff, 0x04, 0xff, 0x06, 0x03, 0xfd, 0xfa, 0xfe, 0x02,
#   0xfc, 0x00, 0x01, 0xfb, 0x02, 0x03, 0x03, 0xfc, 0xfa, 0xff, 0x00, 0xff,
#   0xfb, 0xff, 0xfc, 0xfa, 0xfe, 0xf9, 0xfc, 0xff, 0xfb, 0xfe, 0xfe, 0x01,
#   0xff, 0x01, 0x01, 0xff, 0x03, 0x03, 0x01, 0xfb, 0x00, 0xfb, 0xfb, 0x02,
#   0xfa, 0xff, 0x03, 0xfe, 0x01, 0xfb, 0xf9, 0xfc, 0x01, 0x00, 0x04, 0xfa,
#   0x02, 0xfd, 0xfe, 0xff, 0x01, 0x02, 0x05, 0xfa, 0xfb, 0x00, 0x00, 0xfc,
#   0x01, 0x03, 0xfa, 0x05, 0xfe, 0xfc, 0x02, 0xff, 0x04, 0xfa, 0x01, 0xfc,
#   0xfa, 0xf9, 0xfa, 0xfe, 0x04, 0xfe, 0x03, 0xff, 0xf8, 0xfb, 0x01, 0xfc,
#   0x02, 0x00, 0x01, 0x01, 0x01, 0xfe, 0xfe, 0xff, 0xff, 0x04, 0xff, 0x00,
#   0xfd, 0xfa, 0x04, 0x02, 0x04, 0x01, 0xfe, 0xfb, 0xff, 0x00, 0xf7, 0xff,
#   0xfe, 0xfb, 0xfc, 0x03, 0xfb, 0xfc, 0xff, 0x02, 0x02, 0xfd, 0xfe, 0xff,
#   0xfd, 0xfa, 0x05, 0x04, 0xf8, 0xfb, 0x00, 0x02, 0xf9, 0x01, 0xfc, 0xfc,
#   0xfe, 0x02, 0xff, 0xff, 0x02, 0xfc, 0xfe, 0x00, 0xfc, 0x04, 0xfd, 0xff,
#   0x04, 0x03, 0xfe, 0x01, 0xfe, 0xf9, 0xfe, 0x05, 0x04, 0xf8, 0x01, 0x03,
#   0x00, 0xfa, 0x01, 0xfa, 0x05, 0x04, 0x00, 0x04, 0x04, 0x02, 0xf9, 0x05,
#   0x00, 0x02, 0xfe, 0x05, 0xff, 0x01, 0x01, 0x06, 0xfb, 0xf9, 0xff, 0xfe,
#   0x00, 0xff, 0xff, 0x01, 0x04, 0xfa, 0x02, 0xfd, 0xfb, 0xfd, 0xfb, 0x03,
#   0xff, 0xff, 0x00, 0x03, 0x02, 0xfb, 0xfb, 0xff, 0x00, 0xfa, 0xfc, 0xfe,
#   0xf8, 0xfc, 0x04, 0xfb, 0xff, 0x00, 0x03, 0x03, 0xfa, 0xfa, 0xfa, 0x00,
#   0x02, 0x02, 0x05, 0xff, 0x05, 0x04, 0x04, 0xfe, 0x00, 0xff, 0xfc, 0xfd,
#   0xfb, 0xf8, 0xff, 0x05, 0xfd, 0xf9, 0x04, 0xff, 0x01, 0xfc, 0xfd, 0x01,
#   0x00, 0x02, 0x02, 0xfb, 0xfd, 0xfc, 0xfc, 0x01, 0xfb, 0x00, 0xfd, 0xfb,
#   0xfe, 0xfe, 0xfa, 0x03, 0xf8, 0x03, 0x03, 0x03, 0xfb, 0xff, 0xfc, 0xfa,
#   0x02, 0xfb, 0x02, 0x00, 0x02, 0xfa, 0x05, 0x02, 0xff, 0xfa, 0x04, 0x02,
#   0xfc, 0x03, 0xff, 0x05, 0x01, 0xfa, 0x04, 0xfa, 0x00, 0xfe, 0xf8, 0xfb,
#   0xfc, 0xff, 0xfe, 0xfa, 0x01, 0xfa, 0x02, 0x00, 0x01, 0xfe, 0xfa, 0x00,
#   0xfa, 0x04, 0xfc, 0x04, 0xfb, 0xfb, 0x03, 0xfa, 0x03, 0xfc, 0xff, 0x02,
#   0x04, 0x00, 0x04, 0x02, 0xfe, 0x00, 0x00, 0x04, 0xfd, 0xfe, 0x01, 0xfb,
#   0x00, 0xff, 0x03, 0x00, 0x03, 0xff, 0xfc, 0xfb, 0x00, 0x00, 0xfa, 0x03,
#   0xfe, 0x01, 0xf9, 0x03, 0xfd, 0x05, 0xfd, 0x01, 0xfb, 0xff, 0xfd, 0xfe,
#   0x02, 0xff, 0x00, 0x01, 0xfd, 0xfe, 0xfb, 0x03, 0xfc, 0xf9, 0x04, 0x05,
#   0xfa, 0x01, 0x03, 0xfd, 0x03, 0xfa, 0x02, 0x04, 0xff, 0x03, 0x05, 0x06,
#   0x05, 0xfe, 0xff, 0xfc, 0x03, 0xff, 0x03, 0xfc, 0x05, 0xfc, 0xfb, 0xff,
#   0xfc, 0xff, 0xfd, 0xfc, 0x02, 0x04, 0xfc, 0xff, 0xfb, 0xfc, 0x00, 0x00,
#   0x00, 0xfc, 0xfc, 0xfe, 0x05, 0x00, 0x06, 0xfc, 0xfe, 0xf9, 0x00, 0x00,
#   0xff, 0x02, 0xf9, 0xfe, 0x03, 0xfb, 0xfe, 0xfa, 0x03, 0x04, 0xfa, 0x01,
#   0x04, 0xfd, 0xfe, 0x03, 0xfd, 0x01, 0xfe, 0xfb, 0xfc, 0xfe, 0x05, 0xf9,
#   0xf8, 0xfb, 0x00, 0xfc, 0xfd, 0x04, 0x03, 0xf8, 0x03, 0x01, 0x03, 0x00,
#   0x01, 0x02, 0x01, 0x03, 0xfc, 0xfe, 0xfb, 0x00, 0x03, 0x02, 0x04, 0xfe,
#   0x06, 0x05, 0x02, 0x01, 0xfd, 0xfd, 0xfc, 0xfc, 0x03, 0x01, 0xfb, 0xfd,
#   0x02, 0x03, 0xfd, 0xfd, 0xfb, 0xfc, 0x03, 0x02, 0x00, 0x02, 0xff, 0xfd,
#   0xfd, 0xff, 0xf9, 0x01, 0x03, 0x03, 0x00, 0xfc, 0xfe, 0xfe, 0x01, 0x02,
#   0xfa, 0x00, 0x00, 0x00, 0xfd, 0x03, 0x00, 0x00, 0xfb, 0xfa, 0x03, 0xf9,
#   0x03, 0x03, 0x03, 0x03, 0xfd, 0x05, 0x04, 0x04, 0x04, 0x04, 0xfb, 0x04,
#   0xfe, 0xfc, 0x02, 0xfb, 0x01, 0x04, 0xfd, 0x02, 0x00, 0xfa, 0xff, 0x04,
#   0x04, 0x00, 0xfc, 0x03, 0x03, 0x02, 0x04, 0x01, 0xfd, 0xfe, 0x01, 0xff,
#   0xfc, 0xfd, 0xf9, 0xfe, 0x05, 0xff, 0xfd, 0x05, 0xfb, 0xfe, 0x05, 0x00,
#   0xfa, 0x05, 0xff, 0xfb, 0x03, 0x02, 0x01, 0xfe, 0x02, 0x00, 0xfc, 0x01,
#   0x04, 0x02, 0xfd, 0xf9, 0xfd, 0x02, 0xfc, 0xfb, 0xfd, 0xfe, 0xfa, 0xfc,
#   0xfa, 0xff, 0xfb, 0xfb, 0xfe, 0xfa, 0xff, 0x02, 0xfb, 0x00, 0xfd, 0xfb,
#   0xfd, 0x01, 0xfd, 0x05, 0x00, 0x02, 0xf9, 0x01, 0x00, 0xfc, 0x02, 0xfd,
#   0x02, 0x02, 0x04, 0xfa, 0xfb, 0x01, 0x01, 0x00, 0x05, 0x02, 0x00, 0x00,
#   0x00, 0x00, 0xfd, 0x00, 0xfb, 0x03, 0x02, 0xf9, 0xfb, 0x00, 0xfb, 0xfc,
#   0xfe, 0x03, 0xff, 0x01, 0xfd, 0xff, 0x03, 0x01, 0x02, 0x00, 0xff, 0xff,
#   0xfb, 0xfe, 0xfd, 0xff, 0xf9, 0xfa, 0xfd, 0xfc, 0xfb, 0x05, 0x01, 0x04,
#   0x01, 0x01, 0x03, 0x05, 0xfa, 0x04, 0xf8, 0xfa, 0xf9, 0x02, 0x04, 0x05,
#   0x03, 0x02, 0xfd, 0xfd, 0x00, 0xfb, 0x03, 0x02, 0xfa, 0xff, 0x00, 0xfe,
#   0x06, 0xfe, 0xfa, 0x05, 0xff, 0x01, 0xfb, 0xfe, 0xfe, 0xfc, 0x05, 0x02,
#   0xfb, 0xfd, 0xfb, 0x04, 0xfe, 0x03, 0xfb, 0x03, 0x03, 0x00, 0x05, 0x02,
#   0x04, 0x00, 0x04, 0x04, 0xfd, 0x03, 0x03, 0x00, 0x05, 0xfb, 0x05, 0x01,
#   0xfa, 0x04, 0xfd, 0xfc, 0xf9, 0xfc, 0xfe, 0x03, 0xfa, 0x04, 0x01, 0x01,
#   0xff, 0x04, 0xfb, 0xfd, 0xf8, 0x01, 0xfe, 0x02, 0xfb, 0xff, 0xfc, 0xfe,
#   0x01, 0xfd, 0x00, 0xfe, 0x01, 0xfa, 0xfe, 0xff, 0xfe, 0x01, 0xfb, 0x00,
#   0xfc, 0xff, 0x03, 0x03, 0xfb, 0x04, 0xfb, 0x02, 0x02, 0x04, 0x05, 0x03,
#   0x05, 0x01, 0x01, 0x01, 0x03, 0xfe, 0x00, 0xfe, 0xf8, 0xfb, 0x00, 0xfd,
#   0xf9, 0xfc, 0x03, 0xff, 0xff, 0x02, 0x00, 0x00, 0xfe, 0xfd, 0xfd, 0xfb,
#   0x02, 0xfd, 0x00, 0xfc, 0xfc, 0x00, 0xfd, 0xfb, 0xff, 0xfc, 0xfb, 0xff,
#   0x00, 0x01, 0x05, 0xfe, 0x00, 0x00, 0xfb, 0x04, 0x02, 0x05, 0x02, 0xfc,
#   0xfa, 0xfe, 0x03, 0x01, 0x02, 0x03, 0xfc, 0xff, 0xff, 0xfc, 0x05, 0xfc,
#   0xfe, 0x04, 0xff, 0xfe, 0xfc, 0xfb, 0x03, 0xfd, 0xff, 0xfd, 0x00, 0x03,
#   0xf9, 0xfe, 0x03, 0x02, 0xfc, 0x04, 0x00, 0xf9, 0x02, 0x04, 0x01, 0x02,
#   0xfb, 0x02, 0xff, 0x02, 0xfd, 0x03, 0x00, 0xff, 0xfe, 0x01, 0x03, 0x01,
#   0xfa, 0x04, 0xfd, 0x04, 0x03, 0xf8, 0xfc, 0xfa, 0xfa, 0x05, 0xfd, 0xfa,
#   0x02, 0xfc, 0x03, 0xfc, 0xff, 0xff, 0xfd, 0x00, 0xfb, 0x01, 0x04, 0xf9,
#   0xfa, 0x00, 0x01, 0xfe, 0x06, 0xfb, 0x04, 0xfd, 0x03, 0xfe, 0x04, 0x01,
#   0xfc, 0x06, 0xfe, 0x01, 0x00, 0xfd, 0x04, 0x02, 0xfe, 0x04, 0x03, 0xfc,
#   0xfd, 0xfa, 0xfe, 0xff, 0xf9, 0xfa, 0xf9, 0x02, 0x00, 0xfc, 0xff, 0x05,
#   0xfa, 0xf9, 0xff, 0x02, 0x04, 0xff, 0x06, 0xff, 0xfc, 0x02, 0xfc, 0x04,
#   0xff, 0x05, 0xfa, 0xff, 0x04, 0xfd, 0x04, 0xfa, 0xfb, 0xfd, 0xfd, 0x04,
#   0xfb, 0xfd, 0xfa, 0xff, 0xfc, 0x03, 0x02, 0x03, 0xfb, 0x01, 0xfb, 0x06,
#   0xfa, 0xfe, 0xfb, 0xfd, 0x03, 0x03, 0x03, 0xff, 0xfa, 0x00, 0x00, 0xfa,
#   0xfb, 0x04, 0xff, 0x00, 0x02, 0xfb, 0xff, 0x00, 0xfd, 0xfd, 0xff, 0xfc,
#   0xfe, 0xfc, 0x02, 0x01, 0xf8, 0x02, 0xff, 0x00, 0xfe, 0xf9, 0xfc, 0x05,
#   0x02, 0x00, 0xfd, 0x00, 0x02, 0x05, 0xfb, 0x01, 0xfd, 0xfc, 0x01, 0x02,
#   0x02, 0x01, 0xf9, 0xff, 0x04, 0x02, 0x02, 0xfa, 0x01, 0xfe, 0x04, 0xff,
#   0xfc, 0x02, 0x03, 0xff, 0xfe, 0xfe, 0xff, 0x05, 0x02, 0x01, 0xff, 0xfc,
#   0xf9, 0x00, 0x02, 0xff, 0xf9, 0xfe, 0x05, 0xfd, 0x03, 0x00, 0xfd, 0xfd,
#   0x00, 0xff, 0x03, 0x03, 0xf8, 0x01, 0xfc, 0xfe, 0xfb, 0xff, 0x03, 0x01,
#   0xff, 0xfb, 0x01, 0x04, 0x03, 0x00, 0xfa, 0xfb, 0xff, 0x01, 0x02, 0xff,
#   0x03, 0xff, 0x00, 0xfb, 0xfb, 0xff, 0xff, 0xff, 0x00, 0xfe, 0xfa, 0x00,
#   0x03, 0xfd, 0xfe, 0x00, 0x01, 0x00, 0x01, 0x00, 0xff, 0x00, 0xfe, 0x00,
#   0xfd, 0xfc, 0x02, 0xfe, 0x03, 0xfa, 0x06, 0xfc, 0x05, 0xfe, 0x04, 0xff,
#   0x02, 0x05, 0x02, 0x02, 0xf9, 0x02, 0xfe, 0xfb, 0x01, 0xff, 0xff, 0xfd,
#   0x05, 0xfd, 0xfd, 0x01, 0x00, 0xfd, 0xfe, 0x03, 0x05, 0x03, 0xff, 0xff,
#   0xfe, 0x00, 0xf9, 0x00, 0x03, 0xfa, 0x00, 0x03, 0xf9, 0xfe, 0xfd, 0xfb,
#   0x00, 0xfd, 0x00, 0xfb, 0x04, 0x02, 0x04, 0xf8, 0x03, 0xfb, 0xfe, 0x05,
#   0x03, 0x04, 0xfc, 0xfb, 0x04, 0x05, 0x01, 0x00, 0xfc, 0xfb, 0xfb, 0xf8,
#   0xfe, 0x02, 0x01, 0xf9, 0x02, 0x00, 0x01, 0xfa, 0xfe, 0xfc, 0xfa, 0xff,
#   0x01, 0xfe, 0xfa, 0xfe, 0xfa, 0xff, 0xff, 0xfa, 0x00, 0xfc, 0x04, 0xff,
#   0x02, 0xf8, 0xfd, 0xfe, 0x00, 0x02, 0xfc, 0x03, 0x05, 0x00, 0x00, 0xff,
#   0x02, 0xfa, 0x00, 0xff, 0xfe, 0xfb, 0xff, 0xff, 0xff, 0xfc, 0xfd, 0xff,
#   0xfe, 0xfa, 0x00, 0x00, 0xfb, 0xfb, 0x00, 0x01, 0x02, 0x00, 0x04, 0xfe,
#   0x01, 0x01, 0xfd, 0xfe, 0x00, 0x04, 0x01, 0xf8, 0x04, 0xfd, 0xfa, 0xfa,
#   0xfe, 0x03, 0x04, 0x01, 0xfc, 0x04, 0x03, 0xff, 0xf9, 0x04, 0x03, 0x01,
#   0xfd, 0xff, 0x05, 0x04, 0x00, 0x02, 0x01, 0x00, 0x01, 0xfb, 0xfa, 0xfe,
#   0xfc, 0xff, 0x01, 0x03, 0xfd, 0xff, 0xfa, 0x02, 0xfe, 0x03, 0x02, 0xfa,
#   0xfc, 0x02, 0xfc, 0xfb, 0xfe, 0x00, 0x02, 0xfd, 0x00, 0x01, 0xfd, 0xfc,
#   0xfd, 0xfb, 0x01, 0x03, 0xf9, 0xfc, 0xff, 0x05, 0xf8, 0x00, 0xff, 0xff,
#   0xfa, 0xf9, 0x01, 0x02, 0xfe, 0x04, 0x01, 0xfd, 0xfa, 0xfb, 0x04, 0x00,
#   0x03, 0xfa, 0x03, 0x04, 0xfa, 0xfb, 0x02, 0xfd, 0x03, 0xfa, 0xfc, 0xfc,
#   0x00, 0xfb, 0x00, 0x01, 0xfb, 0x03, 0xff, 0x00, 0xfc, 0x01, 0x00, 0x01,
#   0xfb, 0xfa, 0x03, 0x01, 0xfe, 0xfe, 0xff, 0x01, 0xfc, 0xfb, 0xfb, 0xfc,
#   0x01, 0xfe, 0xfd, 0xf8, 0xfb, 0xfd, 0x06, 0xfb, 0x01, 0x00, 0xff, 0xfe,
#   0x03, 0x02, 0xfa, 0x02, 0xfa, 0xff, 0x00, 0x04, 0xfb, 0x01, 0xfe, 0xfd,
#   0xfa, 0xfb, 0x04, 0x00, 0xfe, 0x04, 0xfd, 0xfb, 0xfe, 0x01, 0x03, 0x01,
#   0x01, 0x00, 0x00, 0x02, 0x05, 0xfb, 0xfe, 0xfd, 0x04, 0xfb, 0xfb, 0xfe,
#   0xfd, 0x02, 0xff, 0xfe, 0x02, 0x02, 0xfc, 0x01, 0xfe, 0x04, 0xfb, 0x04,
#   0x02, 0xfc, 0x01, 0x06, 0x02, 0xfe, 0xfb, 0xfe, 0x00, 0x05, 0x02, 0x00,
#   0xf8, 0x03, 0x02, 0xff, 0x04, 0xfd, 0x05, 0xfc, 0xfd, 0xfd, 0xfd, 0xfe,
#   0xfe, 0xff, 0x00, 0xfb, 0xfe, 0x03, 0xfb, 0xfe, 0x01, 0x03, 0x02, 0x04,
#   0xfa, 0xf9, 0xfe, 0x01, 0xfe, 0xfd, 0x03, 0x04, 0xfd, 0x04, 0x01, 0x03,
#   0x04, 0x03, 0x02, 0xfe, 0xfe, 0x04, 0x06, 0xfa, 0x02, 0xfc, 0xfa, 0x05,
#   0x03, 0xff, 0xfc, 0x04, 0x00, 0xfa, 0x00, 0x04, 0xfd, 0xfe, 0x04, 0x04,
#   0x01, 0xff, 0xfd, 0x00, 0xfe, 0x01, 0xff, 0x02, 0xf9, 0x01, 0x01, 0x00,
#   0x00, 0x04, 0x00, 0xfd, 0xff, 0x04, 0xfd, 0xfc, 0x03, 0x01, 0xfa, 0x04,
#   0xfb, 0xff, 0x02, 0x02, 0xfb, 0x03, 0x01, 0x04, 0xfe, 0x03, 0xfa, 0xfb,
#   0xfc, 0xfa, 0xff, 0xfb, 0x01, 0xfc, 0x05, 0x03, 0xfd, 0x01, 0x00, 0xfe,
#   0xfd, 0x02, 0x04, 0x05, 0x01, 0xfc, 0x04, 0xfc, 0x01, 0x00, 0x05, 0xfd,
#   0x02, 0x04, 0xfe, 0x01, 0x00, 0xfd, 0x00, 0x01, 0xf8, 0xfe, 0x00, 0xfb,
#   0x00, 0xff, 0x02, 0xfa, 0x01, 0xff, 0xfe, 0x00, 0xfe, 0x01, 0xff, 0xf9,
#   0xf9, 0x00, 0x04, 0x01, 0x04, 0x03, 0xff, 0xfb, 0x03, 0xf9, 0x05, 0x00,
#   0x01, 0xfe, 0xfc, 0x03, 0xff, 0x00, 0xff, 0x01, 0xfc, 0x00, 0x00, 0xfa,
#   0xfc, 0x00, 0xfd, 0x01, 0x06, 0x02, 0xfb, 0x00, 0xfd, 0xfb, 0x01, 0xfd,
#   0x01, 0x00, 0x04, 0x05, 0xfb, 0x00, 0xfa, 0x01, 0xfc, 0xff, 0x06, 0x01,
#   0xf9, 0xf8, 0xff, 0x00, 0x02, 0xfb, 0xfe, 0xfe, 0x04, 0xfa, 0x05, 0x03,
#   0xff, 0xfa, 0x01, 0x01, 0x03, 0xfd, 0x02, 0x01, 0x00, 0x02, 0xf9, 0x04,
#   0xf9, 0xfe, 0xfa, 0xf9, 0xfb, 0xfd, 0x01, 0x02, 0xfb, 0xfe, 0xfa, 0xfd,
#   0x06, 0x03, 0x03, 0xfb, 0xfd, 0xfe, 0xfb, 0xfd, 0x05, 0xfd, 0xfc, 0x03,
#   0x02, 0xfc, 0x03, 0x05, 0xfb, 0xfa, 0xfb, 0x05, 0x04, 0x02, 0xfc, 0x02,
#   0x02, 0x00, 0xfe, 0x00, 0x02, 0xfd, 0xfa, 0xfb, 0xfc, 0x05, 0xfb, 0xf9,
#   0xfc, 0xff, 0xfe, 0xff, 0x01, 0xfc, 0xff, 0xf9, 0xfe, 0x03, 0xf9, 0xfe,
#   0xfc, 0x04, 0xf8, 0x04, 0xfd, 0xfc, 0x03, 0xff, 0x00, 0xff, 0x04, 0xfa,
#   0x05, 0x02, 0xfb, 0xfd, 0xfe, 0xfd, 0x00, 0x00, 0xf8, 0x03, 0x03, 0x03,
#   0xfa, 0xff, 0xff, 0x02, 0x01, 0xfb, 0xfc, 0xff, 0x02, 0x02, 0xfd, 0x00,
#   0x06, 0xfc, 0xfe, 0xfb, 0xfe, 0x01, 0x00, 0x04, 0xfa, 0x04, 0x00, 0x00,
#   0xff, 0xfe, 0x02, 0xfc, 0x02, 0xfc, 0x01, 0xfa, 0xfe, 0x01, 0xfe, 0xff,
#   0xfb, 0x01, 0xfd, 0xfd, 0xfa, 0xff, 0xfc, 0xf9, 0xfe, 0xfb, 0xfc, 0xfb,
#   0x04, 0xfc, 0x00, 0xfb, 0xff, 0x04, 0xfb, 0xfd, 0xfa, 0x04, 0xff, 0x02,
#   0x02, 0x06, 0xfb, 0xfa, 0x03, 0xfa, 0xff, 0x04, 0xfc, 0x03, 0x01, 0xfb,
#   0xfe, 0xfd, 0xfb, 0x05, 0x01, 0x05, 0x00, 0x01, 0x05, 0x02, 0x03, 0x03,
#   0xff, 0xfa, 0xfa, 0xff, 0xfe, 0xfc, 0x05, 0x01, 0x04, 0x07, 0x03, 0xfd,
#   0xf9, 0x00, 0xf9, 0x03, 0xf8, 0xfe, 0xfc, 0x03, 0x02, 0xfc, 0xfb, 0x01,
#   0x00, 0xff, 0x00, 0x03, 0x02, 0xff, 0xfc, 0xfe, 0xfc, 0xf9, 0xff, 0xfd,
#   0xfc, 0xff, 0x05, 0xfd, 0xfd, 0x05, 0x02, 0x00, 0xfc, 0x06, 0x03, 0xfc,
#   0x04, 0xfd, 0xfe, 0x00, 0xfa, 0x01, 0x04, 0xfd, 0x04, 0x04, 0x02, 0x05,
#   0xfc, 0x02, 0x05, 0xfd, 0xfd, 0xfe, 0x04, 0xfc, 0xfa, 0x01, 0x05, 0x03,
#   0xfc, 0x02, 0x03, 0x04, 0xfb, 0xfe, 0xf9, 0xfc, 0xfe, 0xfa, 0xfd, 0x02,
#   0x00, 0x03, 0x00, 0xf9, 0xfd, 0xfd, 0x05, 0x06, 0x05, 0x03, 0x05, 0xff,
#   0x04, 0xfb, 0xff, 0xff, 0xfd, 0xfb, 0xfc, 0xfe, 0x03, 0xfb, 0xff, 0xfc,
#   0x06, 0x00, 0xfa, 0xfa, 0x05, 0x01, 0x00, 0x04, 0x02, 0xfa, 0x01, 0x04,
#   0xfd, 0x01, 0x03, 0x06, 0xff, 0x01, 0xfd, 0xfd, 0xff, 0xfc, 0xfb, 0x02,
#   0xfd, 0x03, 0x01, 0x02, 0xfc, 0x05, 0xfd, 0xfd, 0xfb, 0xfe, 0xfa, 0xf8,
#   0x02, 0xfb, 0xfd, 0x00, 0xfe, 0xff, 0x06, 0x00, 0x03, 0x00, 0xfc, 0x02,
#   0xfb, 0xfc, 0x04, 0xfe, 0xfd, 0x04, 0x03, 0x05, 0x03, 0xf7, 0xfa, 0x03,
#   0xff, 0xfb, 0xf9, 0xfd, 0xfc, 0x06, 0x02, 0xf6, 0x03, 0xf8, 0x05, 0x01,
#   0x07, 0x01, 0x03, 0x05, 0x05, 0x02, 0xfe, 0xff, 0xff, 0x04, 0x02, 0x01,
#   0xf8, 0x04, 0x05, 0xf9, 0xfa, 0xf9, 0xff, 0x01, 0xf8, 0x08, 0xfb, 0xfd,
#   0xfd, 0x02, 0xf9, 0x03, 0xfb, 0xfe, 0x00, 0x02, 0xfc, 0xf7, 0x01, 0xfe,
#   0x01, 0x02, 0xfe, 0xf9, 0xfc, 0xfa, 0x03, 0xfc, 0xfb, 0x03, 0x04, 0x03,
#   0x05, 0x00, 0x03, 0x00, 0xfb, 0xf9, 0xfa, 0x05, 0x03, 0x01, 0x01, 0xfb,
#   0xff, 0xff, 0x01, 0xfa, 0xf7, 0x01, 0x04, 0x06, 0x04, 0xfd, 0xfe, 0xfa,
#   0xfc, 0xfd, 0xfc, 0xfc, 0xfc, 0x02, 0xfb, 0xf9, 0xff, 0xfb, 0xfe, 0xf9,
#   0x02, 0xfa, 0x00, 0xfc, 0xfd, 0x00, 0xf9, 0x01, 0xf9, 0xfb, 0x00, 0xfa,
#   0xf8, 0xfc, 0xfb, 0x04, 0x07, 0x00, 0x07, 0x01, 0x00, 0x00, 0xfe, 0xfe,
#   0xfd, 0xfa, 0x02, 0x01, 0x01, 0xf9, 0x03, 0xfa, 0xf9, 0xfa, 0xfc, 0x05,
#   0xfb, 0xff, 0x02, 0xf6, 0x02, 0xf8, 0x00, 0xfd, 0xfd, 0x05, 0xfc, 0x05,
#   0xff, 0xfb, 0xfa, 0x03, 0x00, 0x00, 0xfd, 0xfd, 0xfb, 0xfd, 0xfb, 0xfd,
#   0xfe, 0x03, 0xff, 0xfc, 0xfd, 0xfe, 0xfb, 0xfb, 0xff, 0xfb, 0x05, 0xfa,
#   0x00, 0xfc, 0xfb, 0x02, 0x00, 0xfe, 0x02, 0xfa, 0x00, 0xfc, 0xfa, 0xf7,
#   0xfb, 0xfa, 0xfb, 0xf7, 0xfa, 0xfb, 0x00, 0x03, 0x03, 0xfa, 0xfd, 0xfb,
#   0x04, 0xf8, 0xfd, 0xfd, 0x04, 0x03, 0xfd, 0xfc, 0xfa, 0xf9, 0xff, 0xfd,
#   0xfd, 0x05, 0xff, 0x00, 0xff, 0xfb, 0xfd, 0xfb, 0xff, 0x04, 0xfe, 0xfb,
#   0xfd, 0xfc, 0x00, 0xfe, 0xff, 0xfb, 0xfd, 0xf8, 0x01, 0xfc, 0x00, 0xfa,
#   0xff, 0xfd, 0xfe, 0xfa, 0x00, 0xfb, 0x03, 0xfa, 0xfe, 0xfd, 0x02, 0xfc,
#   0xfb, 0x04, 0xfd, 0xf7, 0x03, 0x02, 0x04, 0x04, 0xff, 0x05, 0xf8, 0xfd,
#   0x02, 0xfd, 0x02, 0xfc, 0xfa, 0xfe, 0xfd, 0xfb, 0xfb, 0xfb, 0x02, 0xf9,
#   0xfc, 0x04, 0xfc, 0xfe, 0xfb, 0x04, 0x00, 0x01, 0x01, 0xfd, 0xfa, 0xf9,
#   0x03, 0xfb, 0x00, 0x02, 0xf8, 0x00, 0xfa, 0xf9, 0xfc, 0x03, 0x02, 0xfa,
#   0x00, 0x04, 0xfb, 0x01, 0x00, 0x03, 0xfa, 0x01, 0x02, 0xfe, 0x06, 0xff,
#   0x00, 0xff, 0xfb, 0x00, 0xfa, 0x00, 0x07, 0xfe, 0xfc, 0x01, 0xfa, 0x00,
#   0x04, 0xfb, 0xfa, 0x02, 0xfe, 0xff, 0x00, 0xfb, 0xf9, 0xfa, 0x02, 0xf9,
#   0x06, 0x00, 0xff, 0x03, 0xfd, 0xfa, 0x00, 0xff, 0x04, 0xff, 0xff, 0x04,
#   0xfc, 0x01, 0xf8, 0x00, 0xfb, 0x03, 0xfb, 0x01, 0x01, 0xfc, 0xfa, 0xfb,
#   0xfe, 0x00, 0xfa, 0x01, 0xff, 0xfc, 0xfb, 0x05, 0x00, 0xfb, 0x04, 0x00,
#   0xf8, 0x04, 0xff, 0xfc, 0x00, 0x02, 0x04, 0x01, 0x02, 0x03, 0x01, 0xff,
#   0x01, 0xf8, 0x05, 0xfd, 0xfb, 0xfa, 0xf9, 0x03, 0xfc, 0x03, 0xff, 0x01,
#   0xfa, 0x05, 0xfe, 0xfa, 0x00, 0xfe, 0x02, 0xfa, 0xf9, 0x02, 0x00, 0xfb,
#   0x01, 0xfe, 0xfb, 0xfd, 0x00, 0x02, 0x00, 0xfe, 0x00, 0xfb, 0x00, 0x02,
#   0x06, 0x00, 0x04, 0xfe, 0xfa, 0xff, 0x01, 0x03, 0xf9, 0x01, 0xfc, 0xfc,
#   0x00, 0x00, 0x03, 0xf9, 0xf8, 0xff, 0xfb, 0xff, 0xfd, 0xfb, 0xff, 0x02,
#   0x03, 0xf8, 0x01, 0x02, 0xfd, 0xfb, 0xf9, 0xfa, 0x01, 0xf9, 0xf8, 0xfa,
#   0x06, 0x05, 0xfa, 0xff, 0x05, 0xfe, 0x01, 0xfd, 0x01, 0xfe, 0xfc, 0xfa,
#   0x02, 0xf8, 0x01, 0xfe, 0xfb, 0x02, 0xfe, 0x01, 0x02, 0xfc, 0xfb, 0x02,
#   0x01, 0xfc, 0x04, 0x02, 0x02, 0x01, 0xfc, 0x03, 0xfe, 0xfb, 0xfb, 0xfb,
#   0xfb, 0x03, 0xf9, 0xfc, 0xff, 0xfb, 0x02, 0xfd, 0x02, 0xf9, 0xfc, 0xfc,
#   0x02, 0x02, 0xff, 0xfd, 0x08, 0xf8, 0xfb, 0x03, 0x05, 0xf9, 0xfa, 0xfe,
#   0xfa, 0xfe, 0xf8, 0x05, 0xff, 0x04, 0x03, 0xfb, 0x04, 0xf9, 0x02, 0xfe,
#   0x03, 0x00, 0xfc, 0xf7, 0x01, 0xff, 0xfb, 0xfd, 0xfb, 0x02, 0x01, 0xff,
#   0xfb, 0x03, 0x00, 0x01, 0x01, 0xff, 0xfc, 0xfb, 0x02, 0xfa, 0x00, 0xf8,
#   0x02, 0x01, 0x03, 0xfa, 0x01, 0xfc, 0xfe, 0xfc, 0xfa, 0x04, 0xfb, 0xfe,
#   0x03, 0xfa, 0x00, 0x02, 0xfc, 0xff, 0xf9, 0x05, 0xff, 0x02, 0xfd, 0xfd,
#   0xfc, 0x02, 0x06, 0xf7, 0xfb, 0xfe, 0x00, 0xff, 0xfd, 0xfc, 0xfc, 0xff,
#   0x00, 0x02, 0x01, 0xfa, 0xfc, 0xf9, 0x00, 0xfc, 0x00, 0xfe, 0xfd, 0xfe,
#   0xfe, 0xfc, 0xfe, 0xfa, 0xfb, 0xfb, 0xfe, 0xfe, 0x03, 0xfd, 0xfa, 0xfe,
#   0x00, 0xfb, 0xfe, 0xf8, 0xf8, 0xfe, 0x01, 0xf9, 0xfc, 0xfd, 0x02, 0xfc,
#   0x00, 0xfd, 0x04, 0xfe, 0xfc, 0xf9, 0x05, 0x00, 0xf9, 0x04, 0x01, 0xfc,
#   0x02, 0xfe, 0x02, 0xfc, 0xfc, 0x04, 0x02, 0xff, 0xfd, 0xfc, 0xf8, 0xfb,
#   0x01, 0x04, 0xff, 0x04, 0x02, 0xf7, 0xfa, 0xff, 0xfe, 0xfe, 0x02, 0xf7,
#   0x00, 0x02, 0xfd, 0xfc, 0x00, 0x00, 0x03, 0xfd, 0x03, 0xfd, 0x02, 0x03,
#   0xff, 0xfb, 0xff, 0xf9, 0xff, 0xf8, 0xff, 0xfa, 0x03, 0xfb, 0x00, 0x04,
#   0x02, 0xf7, 0x01, 0x00, 0xff, 0xfb, 0x00, 0xf7, 0xff, 0x01, 0x04, 0x00,
#   0xfc, 0xfe, 0x02, 0x02, 0x04, 0xfa, 0x04, 0xfb, 0x01, 0xfb, 0xf8, 0xfe,
#   0x08, 0xfe, 0xf9, 0x05, 0x00, 0xff, 0xfa, 0x00, 0x03, 0xfe, 0x02, 0xfa,
#   0xfc, 0xfa, 0xf7, 0x05, 0x00, 0xfe, 0xfd, 0x04, 0xfa, 0x03, 0x00, 0xfd,
#   0x03, 0xfd, 0xfd, 0xff, 0xf9, 0xff, 0x03, 0x02, 0xfc, 0x03, 0x00, 0xff,
#   0xf7, 0x01, 0x01, 0xfe, 0x02, 0xfe, 0x01, 0xff, 0xfc, 0xfe, 0xf6, 0x00,
#   0x02, 0xfc, 0xfb, 0x00, 0xfa, 0x03, 0xff, 0x05, 0xff, 0xfe, 0xfe, 0xfe,
#   0x06, 0xfe, 0x02, 0x01, 0xfb, 0xfd, 0xff, 0xfe, 0xfb, 0xff, 0xff, 0xfe,
#   0xf9, 0x05, 0x07, 0xff, 0xff, 0x09, 0xf8, 0xfa, 0xf8, 0xfd, 0x04, 0x01,
#   0x03, 0xff, 0xfa, 0xfe, 0xfd, 0x00, 0xff, 0xf8, 0x05, 0x00, 0xfb, 0x00,
#   0xfc, 0x00, 0x04, 0xfc, 0xfa, 0xfe, 0xff, 0xfb, 0x02, 0xff, 0xfc, 0x02,
#   0xf9, 0xff, 0xfd, 0xfe, 0x02, 0xfd, 0x04, 0xfb, 0xff, 0x02, 0x02, 0x02,
#   0x05, 0xfe, 0x02, 0xff, 0x01, 0xf7, 0xfd, 0xfe, 0xfe, 0x03, 0x01, 0xfc,
#   0x00, 0xfc, 0x01, 0x04, 0xfd, 0x0a, 0xfb, 0xfb, 0xfd, 0x05, 0xfa, 0x00,
#   0xfb, 0x02, 0xfe, 0x00, 0xfd, 0x00, 0xfb, 0xfa, 0xfc, 0xf8, 0xfa, 0x03,
#   0xf9, 0xff, 0x03, 0xfe, 0xff, 0xfa, 0x04, 0x01, 0x00, 0xf8, 0xff, 0xfb,
#   0xfd, 0x00, 0x03, 0xfa, 0xf9, 0xfc, 0xfa, 0xfd, 0xfc, 0xfd, 0x04, 0xfc,
#   0xfa, 0x04, 0xf8, 0x00, 0xfa, 0x00, 0x00, 0x01, 0xfe, 0xff, 0xfc, 0xf9,
#   0x06, 0x00, 0x02, 0x05, 0x00, 0x01, 0xff, 0xff, 0x03, 0xf8, 0x02, 0x01,
#   0xff, 0x03, 0xfe, 0xfd, 0x02, 0xf9, 0x02, 0xfc, 0x02, 0xfb, 0x05, 0x02,
#   0xfd, 0xfa, 0xfd, 0x03, 0x03, 0xfb, 0x04, 0xfa, 0x01, 0xf9, 0x02, 0xfa,
#   0xf8, 0x02, 0x02, 0xff, 0xf9, 0xfe, 0xfc, 0xfd, 0xfb, 0xf9, 0xfb, 0xf8,
#   0xff, 0xff, 0x01, 0xfc, 0xfc, 0x04, 0xfb, 0xfb, 0x04, 0xf7, 0xfc, 0xfc,
#   0xfe, 0xff, 0x03, 0xf8, 0xfa, 0xff, 0xfc, 0xf9, 0xfb, 0xfb, 0xfe, 0xfe,
#   0xf7, 0x03, 0x01, 0xfb, 0x02, 0xfe, 0xfa, 0xfb, 0xfa, 0xf9, 0xfd, 0xff,
#   0x00, 0xfa, 0x02, 0xfe, 0x06, 0xfc, 0xfc, 0xfa, 0xfe, 0x00, 0x04, 0xfa,
#   0x03, 0xfc, 0xff, 0xfd, 0xfc, 0x01, 0x00, 0xfa, 0xfe, 0xf9, 0x02, 0x02,
#   0x00, 0xff, 0xff, 0x02, 0x03, 0x03, 0xfe, 0xf8, 0xf7, 0xfd, 0xfc, 0xf9,
#   0xff, 0xfa, 0xfd, 0xf9, 0x02, 0xfe, 0xf8, 0xfc, 0x03, 0x04, 0xfc, 0x02,
#   0xfb, 0xff, 0x00, 0x06, 0xff, 0xf7, 0x00, 0xfe, 0xfe, 0xfb, 0xfa, 0x00,
#   0x02, 0xf8, 0x00, 0x01, 0xf9, 0xfc, 0xff, 0xff, 0x04, 0xfe, 0x00, 0xf9,
#   0xf9, 0x00, 0x01, 0xfa, 0x01, 0xfd, 0x00, 0xfe, 0x01, 0xf8, 0xfc, 0xfa,
#   0x02, 0xfb, 0xfe, 0xfd, 0xf9, 0x00, 0xfd, 0x02, 0xfc, 0x01, 0xfd, 0xfe,
#   0xfe, 0xfb, 0xfc, 0xff, 0x04, 0x00, 0x02, 0xf8, 0x06, 0x02, 0x02, 0x02,
#   0xfc, 0x01, 0xf8, 0xfe, 0xfc, 0x01, 0xfc, 0x04, 0xfe, 0xfe, 0xfa, 0x00,
#   0x06, 0xfc, 0xfe, 0x03, 0xfc, 0xfe, 0x03, 0x00, 0xfe, 0xfc, 0x00, 0x04,
#   0x02, 0xff, 0xfa, 0x01, 0xf8, 0x04, 0x05, 0x00, 0xfa, 0x00, 0xfc, 0xfc,
#   0xff, 0x03, 0x04, 0xf8, 0xfe, 0x02, 0x01, 0x02, 0x01, 0xf9, 0xfc, 0xf8,
#   0x04, 0x00, 0xfc, 0xfa, 0x01, 0x08, 0x08, 0xfe, 0xfc, 0x05, 0x01, 0xfa,
#   0xfb, 0xfb, 0x05, 0xfa, 0xf9, 0xfe, 0xfb, 0x01, 0xfe, 0x03, 0x00, 0x01,
#   0xfb, 0x01, 0x00, 0xfd, 0xff, 0x03, 0x02, 0x02, 0x02, 0xf7, 0xfa, 0x02,
#   0xfa, 0x03, 0x00, 0x04, 0x07, 0xff, 0x07, 0xfd, 0xfa, 0x03, 0x01, 0xfe,
#   0x03, 0xfc, 0x01, 0x01, 0xfd, 0xfa, 0x02, 0xfd, 0xff, 0xfe, 0xfb, 0x02,
#   0xfe, 0xfb, 0xf8, 0xff, 0xfa, 0xff, 0x04, 0xfb, 0xfa, 0x06, 0xfe, 0x01,
#   0xfc, 0x05, 0xf9, 0x01, 0x00, 0xfd, 0xf8, 0xfb, 0x01, 0x04, 0x01, 0xfe,
#   0x00, 0x02, 0x03, 0xfd, 0x00, 0xfc, 0xfc, 0xfd, 0x04, 0x07, 0x03, 0xfa,
#   0x00, 0xfb, 0x04, 0x06, 0xfc, 0xfb, 0xfb, 0xff, 0x01, 0xfb, 0x00, 0xfb,
#   0xf8, 0xfd, 0x00, 0xf9, 0xf9, 0xff, 0xfa, 0x02, 0xfa, 0x01, 0xfb, 0x01,
#   0x03, 0x02, 0x00, 0xfc, 0x02, 0xfe, 0xff, 0xf9, 0x03, 0x04, 0xfa, 0xfa,
#   0xf7, 0x01, 0x01, 0x01, 0xff, 0xfb, 0xfd, 0xf8, 0x04, 0xfc, 0x03, 0xf9,
#   0x01, 0xfd, 0x00, 0xff, 0x00, 0xf7, 0x01, 0x01, 0x00, 0x02, 0x02, 0xfc,
#   0xfe, 0x02, 0x01, 0xfc, 0xfe, 0xfb, 0x04, 0x04, 0x01, 0x02, 0xfb, 0x05,
#   0xfe, 0xfb, 0xf7, 0x04, 0xff, 0xfa, 0x00, 0x00, 0x02, 0x04, 0xfa, 0x02,
#   0x03, 0xf8, 0x00, 0xfe, 0xfa, 0x01, 0x02, 0x03, 0x02, 0xfd, 0xfc, 0xfe,
#   0xf8, 0xfd, 0xfe, 0xfd, 0xfe, 0x01, 0xf7, 0xfb, 0xf8, 0xfe, 0x02, 0xf9,
#   0xfd, 0xfe, 0xfb, 0x03, 0xfb, 0xfe, 0x03, 0x01, 0x05, 0xfe, 0xf9, 0x02,
#   0xfb, 0x00, 0x06, 0xfc, 0xfa, 0xfa, 0xfc, 0xff, 0xfb, 0xf8, 0x00, 0xff,
#   0x0a, 0x02, 0x03, 0xfa, 0xfd, 0x00, 0xfc, 0xff, 0x00, 0x00, 0x04, 0xfe,
#   0x04, 0xf7, 0xfe, 0xfd, 0x00, 0xfd, 0x03, 0xf8, 0xf9, 0xfb, 0xf7, 0x01,
#   0xf6, 0xf9, 0x01, 0x02, 0xf9, 0x04, 0xfa, 0xfe, 0xfb, 0x08, 0xfd, 0x04,
#   0x00, 0xfb, 0xfa, 0x01, 0x02, 0xfd, 0x00, 0xf8, 0x04, 0xfd, 0xf6, 0xff,
#   0xff, 0x00, 0x03, 0x00, 0xfe, 0x00, 0x04, 0xf9, 0x02, 0xfc, 0xff, 0xfc,
#   0x01, 0xfb, 0x03, 0x00, 0x01, 0x05, 0x05, 0xfe, 0x01, 0xfe, 0x00, 0xf8,
#   0x00, 0xfe, 0x00, 0x00, 0x03, 0x04, 0xfe, 0x01, 0x03, 0x01, 0x05, 0xfa,
#   0xf7, 0x01, 0xfd, 0x01, 0x00, 0x03, 0xfa, 0x00, 0xfa, 0xff, 0x03, 0xfb,
#   0x00, 0xff, 0x02, 0x00, 0xfc, 0xf8, 0xfa, 0xfc, 0x05, 0xfa, 0xfd, 0xfa,
#   0x01, 0xfc, 0xfc, 0xff, 0xff, 0xff, 0x04, 0xf9, 0xfe, 0x01, 0x02, 0x04,
#   0x05, 0xfd, 0xfc, 0x00, 0xf8, 0xfe, 0xfc, 0x03, 0xf8, 0x01, 0xfa, 0xff,
#   0x04, 0xfc, 0xfd, 0x00, 0x03, 0xfc, 0x06, 0x01, 0xfe, 0x00, 0x04, 0x03,
#   0x02, 0xf9, 0x04, 0xfa, 0xf8, 0xf9, 0xfc, 0x03, 0x03, 0xfe, 0xfa, 0xfb,
#   0x00, 0xfd, 0xfd, 0xfe, 0xfa, 0xfd, 0x02, 0xfb, 0xfa, 0x03, 0x03, 0x01,
#   0xfd, 0xfb, 0x05, 0x01, 0xfe, 0xfb, 0xfa, 0x03, 0xfd, 0x00, 0x05, 0xf8,
#   0xfb, 0xfd, 0x02, 0xfa, 0xfe, 0x02, 0x02, 0xf8, 0xff, 0xff, 0x05, 0x01,
#   0xfd, 0xff, 0x05, 0xfd, 0x02, 0xf8, 0x01, 0xfd, 0xfd, 0x05, 0x00, 0xf7,
#   0xfc, 0xf6, 0x01, 0xf7, 0xf9, 0xff, 0xff, 0xfe, 0x00, 0xfc, 0xfe, 0xfb,
#   0xfd, 0x01, 0xfa, 0xfb, 0xfe, 0xfc, 0xfa, 0xff, 0x00, 0xf9, 0x09, 0x06,
#   0xfb, 0x07, 0x04, 0x00, 0xff, 0xf8, 0xfe, 0xfc, 0xfe, 0x01, 0xfc, 0xfb,
#   0x06, 0xfe, 0xfc, 0xfa, 0x03, 0xfd, 0x01, 0x05, 0x01, 0x03, 0xf8, 0xf9,
#   0xfa, 0xfd, 0xfc, 0x02, 0x01, 0x05, 0xff, 0x04, 0xfd, 0xfd, 0x04, 0x04,
#   0x00, 0x00, 0x05, 0x01, 0x02, 0x03, 0xfd, 0x02, 0xfc, 0xf8, 0x05, 0x01,
#   0xfd, 0xfc, 0x01, 0x00, 0x05, 0x05, 0xfd, 0xfd, 0xfe, 0xfd, 0x04, 0xf8,
#   0xfd, 0xff, 0xff, 0x06, 0xfa, 0x06, 0x04, 0xfa, 0xfc, 0xff, 0xfb, 0x02,
#   0xff, 0x02, 0x01, 0xf8, 0x00, 0x04, 0x00, 0x00, 0xf8, 0x00, 0xfd, 0xfb,
#   0x03, 0x03, 0x02, 0xf9, 0x02, 0x03, 0x04, 0x03, 0xff, 0x03, 0x03, 0xfc,
#   0x05, 0x02, 0x02, 0x09, 0xfa, 0x01, 0xfc, 0x03, 0x01, 0xf8, 0x00, 0xfa,
#   0xff, 0xfe, 0xfb, 0xfe, 0x02, 0xff, 0xf8, 0xfa, 0x02, 0xff, 0x02, 0xfe,
#   0xfa, 0xfb, 0x01, 0xfb, 0xf8, 0xff, 0xf8, 0xfa, 0x00, 0xfd, 0xfd, 0xfe,
#   0xfe, 0x05, 0x01, 0xf7, 0xf8, 0x03, 0xff, 0xf8, 0xff, 0x04, 0x02, 0x02,
#   0xfd, 0x00, 0x00, 0xfa, 0xfd, 0x02, 0xff, 0xfd, 0xf9, 0x03, 0xfa, 0xff,
#   0x03, 0x03, 0x05, 0x06, 0xf9, 0xff, 0xfe, 0xfd, 0x03, 0xfe, 0xfd, 0xfc,
#   0x00, 0xff, 0x03, 0xfc, 0xfc, 0x00, 0x03, 0xf9, 0x01, 0x02, 0xfc, 0x01,
#   0xf8, 0xfa, 0x04, 0xfe, 0xfe, 0xfa, 0xfd, 0xfd, 0xfd, 0xf6, 0xff, 0x04,
#   0xf7, 0x03, 0xfd, 0x03, 0x05, 0x04, 0xfb, 0xff, 0xfa, 0xfb, 0x02, 0xfe,
#   0x03, 0xfc, 0xfa, 0xf8, 0xfd, 0xfc, 0x02, 0xfa, 0xfa, 0xfc, 0x00, 0x01,
#   0xfe, 0xfc, 0x04, 0xfb, 0x02, 0xff, 0x02, 0x02, 0x03, 0x02, 0x01, 0x03,
#   0xfa, 0xff, 0x04, 0xfc, 0xfc, 0x00, 0x00, 0xff, 0x04, 0xfa, 0x04, 0x04,
#   0xfd, 0x00, 0x00, 0x02, 0x02, 0xfd, 0x00, 0xfd, 0xf7, 0x01, 0x02, 0xfa,
#   0xf9, 0xf7, 0x01, 0x05, 0x02, 0xfd, 0x01, 0xff, 0xfb, 0x04, 0xfe, 0xf9,
#   0x02, 0xfb, 0x03, 0xfe, 0xff, 0xfb, 0x03, 0x01, 0xfc, 0xfe, 0xfc, 0x04,
#   0xfa, 0xfb, 0xf7, 0x02, 0xfd, 0xf9, 0x04, 0x04, 0xfc, 0xfe, 0xfb, 0x04,
#   0xfc, 0x01, 0x00, 0x03, 0x03, 0x02, 0xff, 0xfe, 0xfa, 0x02, 0xfc, 0xfd,
#   0xfc, 0x00, 0xfd, 0xff, 0xf9, 0xfd, 0x00, 0xff, 0xfb, 0x01, 0x02, 0x03,
#   0x01, 0xfe, 0xfb, 0x01, 0xff, 0xfd, 0x00, 0x03, 0x04, 0x04, 0x03, 0xfc,
#   0xfc, 0xfa, 0xfa, 0xfd, 0xff, 0xfc, 0xf9, 0xff, 0x00, 0xfb, 0x05, 0xff,
#   0x06, 0xf9, 0x01, 0xfc, 0x00, 0xf9, 0x01, 0x02, 0xff, 0x01, 0x04, 0x03,
#   0x01, 0xfa, 0x02, 0xfa, 0x01, 0xfb, 0xff, 0x02, 0xfb, 0xfb, 0x01, 0xfa,
#   0x00, 0xff, 0xfa, 0xf9, 0xfa, 0xfe, 0x01, 0xf9, 0xf9, 0x02, 0xfc, 0x02,
#   0xf8, 0x05, 0xfb, 0xfb, 0x00, 0xfa, 0xfb, 0x00, 0x01, 0x03, 0x00, 0xf8,
#   0xfa, 0x01, 0x01, 0xfc, 0xfc, 0xf9, 0xff, 0xf9, 0x01, 0x01, 0x02, 0xfd,
#   0x03, 0xf8, 0xff, 0x01, 0x0a, 0xfe, 0xfc, 0xf7, 0x01, 0x02, 0xfb, 0xfd,
#   0xfc, 0xfa, 0x03, 0x00, 0x00, 0x00, 0xff, 0xfe, 0xfd, 0x04, 0xf8, 0x05,
#   0xf9, 0xfe, 0xfd, 0xfa, 0xf8, 0xf8, 0xff, 0xfc, 0xfe, 0xfe, 0xfe, 0xfa,
#   0xfe, 0xf9, 0x01, 0xfc, 0x00, 0xff, 0xfb, 0x02, 0xfe, 0xfe, 0x01, 0xff,
#   0xfb, 0x03, 0x03, 0xfd, 0xfc, 0xf8, 0xf9, 0xfd, 0x01, 0xfb, 0xfa, 0x01,
#   0x01, 0xfe, 0x01, 0xfb, 0x00, 0xf9, 0xfa, 0x00, 0x03, 0xf9, 0xf8, 0xfd,
#   0x02, 0xf9, 0x03, 0x00, 0xfa, 0xfb, 0x02, 0x02, 0xfd, 0x05, 0xfd, 0x00,
#   0x01, 0xfa, 0x02, 0x01, 0xf8, 0xff, 0x00, 0xfa, 0xf9, 0xfc, 0xfc, 0xfb,
#   0xff, 0xfa, 0xff, 0x02, 0xfa, 0xfa, 0xff, 0x05, 0xfd, 0x04, 0x03, 0xf9,
#   0xfd, 0xfe, 0x03, 0x03, 0xf9, 0x01, 0xf8, 0x03, 0x05, 0x01, 0xfd, 0xff,
#   0xfc, 0x02, 0xfa, 0xfd, 0x00, 0xf9, 0xf6, 0x01, 0x01, 0xff, 0xff, 0xff,
#   0x06, 0xfb, 0xfd, 0xff, 0x00, 0x03, 0x03, 0xf9, 0xff, 0xfc, 0x00, 0xf7,
#   0xfe, 0x02, 0x04, 0xfc, 0xff, 0xfa, 0x02, 0xfe, 0xf9, 0xfa, 0x06, 0xf7,
#   0x01, 0xff, 0xfd, 0xfe, 0xfc, 0xf8, 0x00, 0x01, 0xff, 0xfa, 0xf8, 0x04,
#   0xfc, 0xff, 0x00, 0xfe, 0xfe, 0x03, 0xff, 0xfb, 0x00, 0xf8, 0x03, 0xfc,
#   0xfc, 0xfe, 0x02, 0xf9, 0xff, 0x01, 0xfe, 0xf7, 0xfb, 0x05, 0xff, 0xfb,
#   0x05, 0x02, 0xfc, 0xfe, 0x01, 0xf8, 0xfd, 0x00, 0xfd, 0xf9, 0xfe, 0xf9,
#   0x01, 0xff, 0x03, 0x05, 0xff, 0xfc, 0x04, 0x01, 0xf9, 0xf8, 0xf9, 0xff,
#   0xf8, 0xfc, 0x01, 0xfd, 0xfc, 0x04, 0x03, 0xff, 0xfa, 0x00, 0x02, 0xfc,
#   0xfa, 0x08, 0x01, 0xfc, 0xf7, 0x05, 0xfb, 0x02, 0x01, 0x05, 0xfb, 0xfd,
#   0x02, 0xfa, 0xfb, 0xff, 0x00, 0xfa, 0x01, 0xfd, 0xff, 0xfa, 0x04, 0xfb,
#   0x02, 0xfa, 0xf8, 0xfd, 0xfe, 0xf8, 0x01, 0x02, 0x04, 0x02, 0x02, 0x05,
#   0xfa, 0x01, 0xfc, 0xf7, 0xfe, 0x02, 0xfa, 0x06, 0xfc, 0xfd, 0x04, 0xfa,
#   0xeb, 0xf7, 0xf2, 0xf1, 0x4a, 0x01, 0xfe, 0x27, 0x0f, 0x06, 0xdc, 0xf1,
#   0xf1, 0xf4, 0xff, 0xf3, 0xf8, 0x14, 0xee, 0xeb, 0xf8, 0xe9, 0xdf, 0x09,
#   0xec, 0x01, 0x17, 0x02, 0x0b, 0x18, 0x08, 0x17, 0xf3, 0x29, 0x01, 0xea,
#   0xfd, 0x04, 0xf4, 0x10, 0xf3, 0x29, 0x05, 0x05, 0xfb, 0x01, 0xfb, 0xf8,
#   0xd6, 0xdd, 0x07, 0xea, 0x00, 0x33, 0x04, 0x14, 0x1f, 0x0e, 0x03, 0xf7,
#   0x0d, 0x00, 0xfb, 0x23, 0xc0, 0xe8, 0xec, 0xff, 0x0e, 0xfc, 0x02, 0x3b,
#   0xe9, 0xf4, 0xcd, 0xfc, 0x03, 0x19, 0xfc, 0x0a, 0x23, 0xff, 0xf9, 0x1d,
#   0xf7, 0xef, 0x01, 0xe9, 0x01, 0x08, 0xfb, 0xdf, 0x09, 0x28, 0x04, 0xfd,
#   0xfd, 0x0f, 0xff, 0x01, 0xfb, 0x36, 0x13, 0xe7, 0x01, 0xe7, 0x12, 0xfd,
#   0x03, 0x0f, 0xfe, 0xeb, 0xf5, 0xfe, 0xf9, 0xf8, 0xfd, 0x2b, 0xdc, 0x2e,
#   0x1e, 0x05, 0x01, 0xec, 0x18, 0x03, 0xfd, 0x2a, 0x0e, 0x21, 0x02, 0x0d,
#   0xe6, 0xf3, 0xff, 0x18, 0x12, 0xea, 0xc6, 0x0d, 0x1d, 0x12, 0x03, 0xed,
#   0xfb, 0x0e, 0x19, 0xfc, 0xfa, 0xff, 0xf3, 0x11, 0x19, 0x05, 0xdc, 0x06,
#   0xff, 0xff, 0xe9, 0x03, 0xf6, 0xf7, 0xfe, 0x08, 0x02, 0xdb, 0x15, 0xe7,
#   0xf4, 0x22, 0xfd, 0x0a, 0xfb, 0xee, 0x01, 0xf9, 0xea, 0x03, 0x0d, 0x1c,
#   0x01, 0xeb, 0x13, 0x10, 0xfd, 0x26, 0x03, 0x23, 0x05, 0x07, 0xfb, 0x17,
#   0x19, 0x05, 0x18, 0xf9, 0xee, 0x1f, 0x03, 0xfa, 0xea, 0xf4, 0xe5, 0x0f,
#   0xf1, 0x06, 0xfc, 0xf4, 0xfb, 0xfc, 0xf2, 0xe1, 0x04, 0x06, 0xf0, 0xff,
#   0x0f, 0xf2, 0xf7, 0x07, 0x13, 0x23, 0xe1, 0x04, 0xfe, 0x0a, 0xff, 0x04,
#   0xfc, 0x0a, 0x0c, 0x11, 0x0c, 0x1c, 0x27, 0xfd, 0xfa, 0x0d, 0x03, 0xf7,
#   0x09, 0xe2, 0xf9, 0xf9, 0x04, 0x0d, 0x03, 0x10, 0xff, 0x18, 0xfd, 0x1c,
#   0x21, 0xfc, 0xfb, 0x22, 0x04, 0x11, 0xfe, 0xf9, 0xed, 0xf0, 0x02, 0x0f,
#   0x03, 0xfe, 0x06, 0xfa, 0x1f, 0xee, 0xfd, 0xed, 0x01, 0xea, 0xf2, 0xe1,
#   0xf5, 0x0c, 0x11, 0xec, 0xef, 0x0c, 0xf7, 0x07, 0x04, 0x08, 0xfe, 0x12,
#   0x2a, 0xf2, 0xfa, 0x0b, 0xfb, 0x42, 0x1f, 0xfd, 0x32, 0x0c, 0x16, 0xef,
#   0xf7, 0x10, 0x04, 0xf9, 0xf6, 0x0a, 0xeb, 0xe8, 0x00, 0xea, 0xf7, 0xf4,
#   0x1e, 0xe5, 0x06, 0x1e, 0xfb, 0xff, 0xfb, 0x23, 0xee, 0xd3, 0x0c, 0x05,
#   0x1b, 0xf7, 0x00, 0x15, 0xd2, 0x1d, 0xfa, 0x0c, 0x06, 0x02, 0xfb, 0xfd,
#   0x03, 0x24, 0xf3, 0x07, 0x02, 0xf3, 0xdc, 0x1a, 0xf9, 0xfc, 0x18, 0xe9,
#   0x08, 0xd8, 0xf2, 0xf2, 0xfb, 0x02, 0xfd, 0x17, 0xfd, 0x15, 0x04, 0xf3,
#   0xf2, 0x0d, 0x28, 0xe3, 0xf8, 0x12, 0x02, 0xff, 0xe7, 0x03, 0xf1, 0x06,
#   0x02, 0xe5, 0x09, 0x07, 0x2c, 0xfc, 0x00, 0x09, 0x02, 0x03, 0xfe, 0x1c,
#   0x12, 0xf1, 0x0d, 0xf6, 0xf8, 0xfd, 0x06, 0x05, 0x10, 0x03, 0xe9, 0x02,
#   0x05, 0x25, 0x02, 0xef, 0x06, 0xdf, 0xfc, 0x0c, 0x1d, 0xe2, 0xd6, 0xf8,
#   0x10, 0x08, 0x10, 0x05, 0x10, 0x00, 0x1d, 0xf5, 0x0b, 0x05, 0x04, 0xf2,
#   0xfd, 0x0c, 0xe9, 0xfb, 0x16, 0x05, 0x0c, 0x01, 0xfb, 0xdd, 0xfe, 0x12,
#   0x0e, 0xea, 0x0c, 0x0c, 0xfb, 0x0e, 0x14, 0xe8, 0x02, 0x13, 0x01, 0x04,
#   0x0e, 0x0a, 0x04, 0xf6, 0x08, 0x05, 0x02, 0xf3, 0x13, 0x14, 0x02, 0xf7,
#   0x15, 0x0b, 0xfe, 0xff, 0xf9, 0x07, 0x06, 0xfd, 0x0d, 0xf7, 0xe1, 0x04,
#   0xf7, 0x07, 0xf1, 0xf2, 0x10, 0xfd, 0xf8, 0x09, 0x03, 0xfa, 0x0b, 0xee,
#   0x18, 0xf7, 0x06, 0xe6, 0xfe, 0x14, 0x10, 0xea, 0x06, 0xd7, 0x0b, 0xe2,
#   0x05, 0x02, 0xfd, 0xfd, 0x05, 0x13, 0x02, 0xf9, 0x05, 0x0a, 0xf7, 0x0a,
#   0x1a, 0x10, 0xfb, 0x0f, 0xeb, 0x01, 0x08, 0x14, 0x00, 0x1b, 0x01, 0x0a,
#   0xf0, 0xf6, 0xff, 0xff, 0x20, 0xff, 0xf8, 0x16, 0x14, 0x0b, 0x01, 0x04,
#   0x0c, 0x02, 0xf3, 0xf2, 0xea, 0x04, 0xf7, 0xec, 0x11, 0xff, 0xfd, 0x08,
#   0x06, 0xf9, 0x04, 0x10, 0x07, 0xf9, 0x06, 0xed, 0xff, 0x0c, 0xf8, 0xfc,
#   0x0c, 0x00, 0x01, 0x05, 0x04, 0x01, 0x02, 0xfb, 0xf5, 0xf7, 0xf7, 0x1d,
#   0xfe, 0x0a, 0xe7, 0xfd, 0x11, 0x09, 0x03, 0x1a, 0x19, 0x09, 0x01, 0x2b,
#   0xfe, 0x03, 0x1d, 0xfb, 0x00, 0x05, 0x02, 0xfb, 0x11, 0x1a, 0xf7, 0x16,
#   0x07, 0x15, 0x06, 0x08, 0xe9, 0x12, 0xf2, 0xfc, 0x12, 0xf1, 0x0d, 0xd3,
#   0x14, 0x09, 0xf1, 0xf5, 0xff, 0xe3, 0x10, 0x0c, 0xff, 0x1f, 0xfb, 0xfc,
#   0x01, 0x22, 0x18, 0xf4, 0xe4, 0x08, 0x08, 0x2a, 0xfd, 0x11, 0x02, 0x00,
#   0x02, 0xf1, 0x07, 0xd6, 0x00, 0x18, 0x04, 0xea, 0x16, 0x02, 0x03, 0x0f,
#   0xf9, 0x03, 0x00, 0x0a, 0x33, 0x1b, 0x04, 0x11, 0xfd, 0xf0, 0x01, 0x10,
#   0xf5, 0x27, 0xfd, 0x0d, 0xf4, 0xe8, 0xfb, 0x09, 0xe1, 0x07, 0x05, 0xf4,
#   0xde, 0xe3, 0x0d, 0xe0, 0x02, 0xf7, 0x03, 0x0f, 0xfa, 0xe6, 0xf5, 0x0d,
#   0x1d, 0x21, 0xff, 0x0b, 0x00, 0x16, 0x15, 0xe4, 0xf0, 0xf1, 0xfc, 0x1e,
#   0xfe, 0xf9, 0xfb, 0x11, 0xed, 0xfb, 0x0b, 0xf9, 0xfe, 0xf2, 0xfe, 0xf7,
#   0x17, 0xef, 0xfb, 0x0f, 0xf8, 0x04, 0xfd, 0x10, 0x19, 0xf1, 0xee, 0x14,
#   0x04, 0xee, 0xfc, 0xe8, 0xf7, 0x1a, 0xec, 0x13, 0xe3, 0xec, 0x04, 0x03,
#   0xfa, 0xe5, 0x02, 0xf6, 0x08, 0x05, 0xeb, 0xed, 0xf4, 0xfc, 0x30, 0x00,
#   0x02, 0x15, 0x26, 0x1d, 0x0f, 0xfb, 0xfe, 0x05, 0xfc, 0x0f, 0x17, 0xe8,
#   0x22, 0x0d, 0xf4, 0xe8, 0x00, 0x08, 0x00, 0xfb, 0xed, 0xd0, 0xcf, 0x04,
#   0x06, 0xfe, 0xee, 0x29, 0x13, 0xeb, 0xff, 0xf9, 0xec, 0x07, 0x01, 0xf4,
#   0x05, 0x17, 0x15, 0x00, 0xfd, 0xf4, 0x04, 0x07, 0xfa, 0xf6, 0x15, 0xf3,
#   0x18, 0xea, 0x02, 0x0b, 0xf5, 0x00, 0xfd, 0x0c, 0x19, 0xed, 0xeb, 0x03,
#   0xe8, 0x06, 0x0e, 0xf0, 0x01, 0xfa, 0x05, 0xf9, 0xd3, 0x16, 0x00, 0x22,
#   0xf9, 0xe3, 0xfd, 0xd6, 0x00, 0x0d, 0x25, 0x06, 0xf9, 0xdb, 0x01, 0xf4,
#   0x0f, 0xf9, 0x13, 0x17, 0x00, 0x23, 0x21, 0xdd, 0x01, 0x07, 0xfc, 0xf8,
#   0x03, 0x04, 0x01, 0xf7, 0x11, 0x12, 0x24, 0x2c, 0x11, 0xf9, 0x04, 0xf0,
#   0x0a, 0xf9, 0x0b, 0x02, 0xfc, 0xfb, 0xfc, 0x0d, 0x1d, 0xfc, 0xf9, 0xe3,
#   0x1a, 0x14, 0x05, 0xee, 0xf2, 0xfa, 0xee, 0x10, 0xea, 0xff, 0x28, 0x0e,
#   0xf4, 0x1c, 0xff, 0xfc, 0xfd, 0xfa, 0xdd, 0xef, 0x10, 0x20, 0x1d, 0xf2,
#   0xf8, 0xe0, 0xfc, 0x12, 0x24, 0xe8, 0x22, 0x27, 0x04, 0x0c, 0x04, 0x04,
#   0xeb, 0xf6, 0x04, 0xf9, 0xc2, 0x05, 0xfb, 0xf2, 0xf9, 0xfc, 0x22, 0x25,
#   0x0b, 0xfb, 0xfd, 0x04, 0x13, 0xe8, 0xde, 0x19, 0x09, 0x0a, 0x05, 0x01,
#   0xf1, 0xf5, 0x0c, 0xeb, 0x02, 0x08, 0xf7, 0xec, 0xf7, 0x03, 0xde, 0x0c,
#   0xe7, 0x2b, 0xfc, 0x1a, 0xed, 0xf2, 0x06, 0x00, 0xfb, 0x2e, 0x18, 0xf2,
#   0x0e, 0x36, 0x0f, 0x10, 0xff, 0x1d, 0xfe, 0x0d, 0x06, 0xde, 0x0f, 0xf4,
#   0xfc, 0xf1, 0xe9, 0x02, 0x15, 0x09, 0x04, 0xfa, 0xe3, 0x06, 0xf9, 0xee,
#   0xfc, 0x29, 0xf4, 0x08, 0x03, 0x25, 0x04, 0x20, 0x03, 0x10, 0xd6, 0xdf,
#   0x16, 0x04, 0x01, 0xff, 0xf9, 0x10, 0x09, 0xfd, 0x11, 0xf7, 0x10, 0xd6,
#   0x03, 0x02, 0xd9, 0xfb, 0x07, 0x1f, 0xf2, 0xe4, 0x0d, 0x0d, 0x05, 0xef,
#   0xff, 0x14, 0x24, 0xfc, 0x23, 0xec, 0x1f, 0x48, 0xf7, 0xe8, 0x00, 0x10,
#   0x15, 0xfa, 0x20, 0xea, 0x03, 0x16, 0xf8, 0x08, 0x0f, 0x24, 0x03, 0x06,
#   0xf9, 0xfb, 0xfd, 0xde, 0x22, 0x1c, 0x25, 0xe2, 0x02, 0xf6, 0xfd, 0x0b,
#   0x00, 0x1e, 0x13, 0x20, 0x17, 0x25, 0x01, 0xf7, 0x0a, 0x07, 0x15, 0x20,
#   0x18, 0x0d, 0x11, 0x0b, 0xf4, 0x03, 0xf8, 0x1c, 0xfb, 0x0c, 0xfa, 0x0c,
#   0x1c, 0x06, 0x02, 0xf6, 0x04, 0x1a, 0x16, 0xf7, 0xef, 0x08, 0xee, 0x32,
#   0xf8, 0xe1, 0x02, 0x06, 0xf9, 0xea, 0x1b, 0x06, 0xfa, 0xf0, 0xfe, 0xf5,
#   0x0b, 0xfc, 0xfd, 0x02, 0x07, 0xfc, 0xfc, 0xeb, 0xe0, 0xfb, 0x1b, 0x43,
# ...
#   0x61, 0x6c, 0x2f, 0x6d, 0x61, 0x78, 0x5f, 0x70, 0x6f, 0x6f, 0x6c, 0x69,
#   0x6e, 0x67, 0x32, 0x64, 0x2f, 0x4d, 0x61, 0x78, 0x50, 0x6f, 0x6f, 0x6c,
#   0x00, 0x00, 0x00, 0x00, 0x04, 0x00, 0x00, 0x00, 0x01, 0x00, 0x00, 0x00,
#   0x0f, 0x00, 0x00, 0x00, 0x0f, 0x00, 0x00, 0x00, 0x20, 0x00, 0x00, 0x00,
#   0xfc, 0xf6, 0xff, 0xff, 0xac, 0x00, 0x00, 0x00, 0x0b, 0x00, 0x00, 0x00,
#   0x24, 0x00, 0x00, 0x00, 0x1c, 0x00, 0x00, 0x00, 0x04, 0x00, 0x00, 0x00,
#   0x04, 0x00, 0x00, 0x00, 0xff, 0xff, 0xff, 0xff, 0x1e, 0x00, 0x00, 0x00,
#   0x1e, 0x00, 0x00, 0x00, 0x20, 0x00, 0x00, 0x00, 0xe8, 0xf6, 0xff, 0xff,
#   0x7b, 0x00, 0x00, 0x00, 0x73, 0x65, 0x71, 0x75, 0x65, 0x6e, 0x74, 0x69,
#   0x61, 0x6c, 0x2f, 0x63, 0x6f, 0x6e, 0x76, 0x32, 0x64, 0x2f, 0x52, 0x65,
#   0x6c, 0x75, 0x3b, 0x73, 0x65, 0x71, 0x75, 0x65, 0x6e, 0x74, 0x69, 0x61,
#   0x6c, 0x2f, 0x63, 0x6f, 0x6e, 0x76, 0x32, 0x64, 0x2f, 0x42, 0x69, 0x61,
#   0x73, 0x41, 0x64, 0x64, 0x3b, 0x73, 0x65, 0x71, 0x75, 0x65, 0x6e, 0x74,
#   0x69, 0x61, 0x6c, 0x2f, 0x63, 0x6f, 0x6e, 0x76, 0x32, 0x64, 0x2f, 0x43,
#   0x6f, 0x6e, 0x76, 0x32, 0x44, 0x3b, 0x73, 0x65, 0x71, 0x75, 0x65, 0x6e,
#   0x74, 0x69, 0x61, 0x6c, 0x2f, 0x63, 0x6f, 0x6e, 0x76, 0x32, 0x64, 0x2f,
#   0x42, 0x69, 0x61, 0x73, 0x41, 0x64, 0x64, 0x2f, 0x52, 0x65, 0x61, 0x64,
#   0x56, 0x61, 0x72, 0x69, 0x61, 0x62, 0x6c, 0x65, 0x4f, 0x70, 0x2f, 0x72,
#   0x65, 0x73, 0x6f, 0x75, 0x72, 0x63, 0x65, 0x00, 0x04, 0x00, 0x00, 0x00,
#   0x01, 0x00, 0x00, 0x00, 0x1e, 0x00, 0x00, 0x00, 0x1e, 0x00, 0x00, 0x00,
#   0x20, 0x00, 0x00, 0x00, 0x12, 0xf8, 0xff, 0xff, 0x00, 0x00, 0x00, 0x09,
#   0x64, 0x05, 0x00, 0x00, 0x0a, 0x00, 0x00, 0x00, 0x3c, 0x05, 0x00, 0x00,
#   0x10, 0x00, 0x00, 0x00, 0x0c, 0x00, 0x14, 0x00, 0x04, 0x00, 0x08, 0x00,
#   0x0c, 0x00, 0x10, 0x00, 0x0c, 0x00, 0x00, 0x00, 0x20, 0x04, 0x00, 0x00,
#   0x18, 0x03, 0x00, 0x00, 0x10, 0x02, 0x00, 0x00, 0x04, 0x00, 0x00, 0x00,
#   0x40, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x40, 0x00, 0x00, 0x00, 0xec, 0xde, 0xd5, 0x3b,
#   0x86, 0x56, 0xb4, 0x3b, 0x9d, 0x67, 0xf0, 0x3b, 0x75, 0x72, 0xc1, 0x3b,
#   0xd9, 0xde, 0x99, 0x3b, 0xb4, 0x92, 0xf8, 0x3b, 0x8b, 0x16, 0x8f, 0x3a,
#   0x59, 0x3a, 0xc5, 0x3b, 0xfb, 0x3e, 0xbd, 0x3b, 0xe9, 0x10, 0xad, 0x3b,
#   0xf1, 0x84, 0x08, 0x3c, 0xbb, 0xab, 0xa4, 0x3b, 0xbe, 0xa8, 0xc7, 0x3b,
#   0x7d, 0x5b, 0x9f, 0x3b, 0xdb, 0x2a, 0x87, 0x3a, 0xdb, 0x74, 0xc1, 0x3b,
#   0x85, 0xc3, 0x8e, 0x3b, 0xfd, 0x98, 0xc5, 0x3b, 0x72, 0x62, 0x9c, 0x3b,
#   0x7e, 0xb9, 0x1d, 0x3c, 0x08, 0x36, 0xcd, 0x3b, 0xb7, 0x8e, 0x04, 0x3c,
#   0x2b, 0x1b, 0x1e, 0x3c, 0x44, 0xc1, 0xcd, 0x3b, 0x17, 0x85, 0x83, 0x3b,
#   0x88, 0x42, 0xf3, 0x3a, 0xa9, 0x24, 0xd7, 0x3b, 0x88, 0xb9, 0xa5, 0x3b,
#   0xc8, 0x6f, 0x9a, 0x3b, 0xb1, 0xcc, 0xb4, 0x3b, 0x48, 0x2d, 0xa2, 0x3b,
#   0x50, 0x88, 0x14, 0x3c, 0xe1, 0x45, 0xbd, 0x3b, 0x88, 0x2a, 0xb0, 0x3b,
#   0xbd, 0xbd, 0xa3, 0x3a, 0x8f, 0xe7, 0xcf, 0x3b, 0x56, 0xf0, 0xbf, 0x3a,
#   0x14, 0x8a, 0x45, 0x3c, 0xb9, 0xe4, 0xbf, 0x3b, 0x59, 0x9d, 0xb0, 0x3b,
#   0x47, 0xb2, 0x01, 0x3c, 0x2f, 0x93, 0xef, 0x3b, 0x57, 0xb4, 0xc5, 0x3b,
#   0xe0, 0xca, 0xdd, 0x3b, 0x1c, 0x6b, 0xa6, 0x3a, 0x11, 0xef, 0xe5, 0x3b,
#   0xfa, 0x5e, 0x96, 0x3a, 0xfe, 0x41, 0x38, 0x3c, 0xd8, 0x91, 0xd5, 0x3b,
#   0x69, 0xdc, 0xe2, 0x3b, 0xe2, 0xaf, 0xc4, 0x3b, 0x5b, 0x89, 0xe0, 0x3b,
#   0x46, 0x6b, 0x4a, 0x3a, 0xf6, 0x82, 0xe5, 0x3b, 0x78, 0xda, 0xca, 0x3b,
#   0xb2, 0xf4, 0x8d, 0x3b, 0xad, 0x59, 0xae, 0x3b, 0x81, 0x9e, 0xe5, 0x3b,
#   0x4a, 0x7c, 0x9b, 0x3a, 0x38, 0xfc, 0x9c, 0x3b, 0x99, 0x97, 0xbe, 0x3b,
#   0xd8, 0x34, 0xb2, 0x3a, 0x36, 0x42, 0x8d, 0x3a, 0x7f, 0xca, 0x89, 0x3b,
#   0x40, 0x00, 0x00, 0x00, 0x00, 0xfc, 0x15, 0x3f, 0x05, 0x22, 0x12, 0x3f,
#   0xf2, 0xcf, 0x16, 0x3f, 0x0c, 0xbf, 0xca, 0x3e, 0x9c, 0xbb, 0xe4, 0x3e,
#   0xfc, 0x4f, 0x41, 0x3f, 0x7a, 0xbf, 0xa8, 0x3d, 0xdd, 0x31, 0x07, 0x3f,
#   0x6c, 0x3f, 0x38, 0x3f, 0xa8, 0x15, 0xff, 0x3e, 0x3f, 0x42, 0x0c, 0x3f,
#   0x61, 0xfd, 0x1b, 0x3f, 0xc9, 0xf2, 0xdd, 0x3e, 0xc6, 0x1c, 0x1e, 0x3f,
#   0x4b, 0x0b, 0x9f, 0x3d, 0x60, 0x18, 0x26, 0x3f, 0xf7, 0x27, 0xc6, 0x3e,
#   0xbf, 0x45, 0xf0, 0x3e, 0xad, 0x29, 0x1b, 0x3f, 0xae, 0xaa, 0x4c, 0x3f,
#   0xf7, 0xf6, 0xb3, 0x3e, 0x6b, 0x4f, 0xc5, 0x3e, 0x87, 0x82, 0x86, 0x3e,
#   0x82, 0xe3, 0xd5, 0x3e, 0x0d, 0x7e, 0x02, 0x3f, 0x38, 0x28, 0x10, 0x3e,
#   0x60, 0xf4, 0x0a, 0x3f, 0x41, 0x47, 0xfb, 0x3e, 0x98, 0x00, 0x03, 0x3f,
#   0xca, 0x4f, 0x05, 0x3f, 0x1d, 0xcd, 0xfc, 0x3e, 0x7c, 0x05, 0x24, 0x3f,
#   0x5a, 0x0c, 0x16, 0x3f, 0x1e, 0xd2, 0x1c, 0x3f, 0x6c, 0xc3, 0xd2, 0x3d,
#   0xd0, 0xa0, 0xfe, 0x3e, 0x2b, 0xc7, 0xb9, 0x3d, 0x1b, 0xc2, 0x34, 0x3f,
#   0xa8, 0x21, 0x14, 0x3f, 0x62, 0x7c, 0x22, 0x3f, 0x22, 0xb2, 0xec, 0x3e,
#   0xf3, 0x96, 0x16, 0x3f, 0x29, 0x50, 0x04, 0x3f, 0x58, 0xd6, 0x05, 0x3f,
#   0x73, 0x29, 0xe4, 0x3d, 0xd4, 0xb0, 0x06, 0x3f, 0x77, 0x9c, 0x92, 0x3d,
#   0x3d, 0xd6, 0x09, 0x3f, 0x5d, 0x16, 0x14, 0x3f, 0xbd, 0x5d, 0x15, 0x3f,
#   0x91, 0xd3, 0x1a, 0x3f, 0x88, 0x62, 0x1f, 0x3f, 0xa9, 0x35, 0x9f, 0x3d,
#   0xaa, 0x31, 0xfb, 0x3e, 0xc3, 0x44, 0x49, 0x3f, 0x8c, 0x27, 0x09, 0x3f,
#   0x77, 0x0f, 0x14, 0x3f, 0xbd, 0x1d, 0xfc, 0x3e, 0x6f, 0xa2, 0xb8, 0x3d,
#   0x4a, 0x05, 0xc5, 0x3e, 0xc4, 0x84, 0x16, 0x3f, 0xea, 0x82, 0xb1, 0x3d,
#   0xd7, 0xd9, 0xd0, 0x3d, 0xc7, 0xb3, 0xb8, 0x3e, 0x40, 0x00, 0x00, 0x00,
#   0x2e, 0x33, 0x54, 0xbf, 0xd9, 0xed, 0x32, 0xbf, 0xce, 0x86, 0x6e, 0xbf,
#   0x90, 0xef, 0x3f, 0xbf, 0x1b, 0xab, 0x18, 0xbf, 0x8f, 0xa1, 0x76, 0xbf,
#   0x5e, 0xf8, 0x0d, 0xbe, 0xe4, 0xaf, 0x43, 0xbf, 0x7d, 0xc4, 0x3b, 0xbf,
#   0xc7, 0xb6, 0x2b, 0xbf, 0xe7, 0x73, 0x87, 0xbf, 0x64, 0x62, 0x23, 0xbf,
#   0x6d, 0x19, 0x46, 0xbf, 0x60, 0xc7, 0x14, 0xbf, 0x85, 0x1c, 0x06, 0xbe,
#   0xf1, 0xf1, 0x3f, 0xbf, 0xfe, 0xa5, 0x0d, 0xbf, 0xcb, 0x0d, 0x44, 0xbf,
#   0x2a, 0xaa, 0x09, 0xbf, 0x0b, 0x7e, 0x9c, 0xbf, 0x9c, 0x9b, 0x4b, 0xbf,
#   0x9a, 0x85, 0x83, 0xbf, 0xf5, 0xde, 0x9c, 0xbf, 0xc1, 0x25, 0x4c, 0xbf,
#   0x47, 0x31, 0xb0, 0xbe, 0x03, 0x5c, 0x71, 0xbe, 0x60, 0x76, 0x55, 0xbf,
#   0x15, 0x6e, 0x24, 0xbf, 0xe8, 0x3a, 0x19, 0xbf, 0x18, 0x63, 0x33, 0xbf,
#   0xed, 0xe8, 0x20, 0xbf, 0x3f, 0x5f, 0x93, 0xbf, 0x55, 0xcb, 0x3b, 0xbf,
#   0x33, 0xca, 0x2e, 0xbf, 0x42, 0x76, 0x22, 0xbe, 0xc0, 0x47, 0x4e, 0xbf,
#   0x75, 0x70, 0x3e, 0xbe, 0x00, 0xff, 0xc3, 0xbf, 0xf0, 0x64, 0x3e, 0xbf,
#   0x1e, 0x3c, 0x2f, 0xbf, 0xe2, 0xae, 0x80, 0xbf, 0x09, 0xb4, 0x6d, 0xbf,
#   0xee, 0x28, 0x44, 0xbf, 0x4a, 0x0f, 0x5c, 0xbf, 0x46, 0x1e, 0x25, 0xbe,
#   0x33, 0x23, 0x64, 0xbf, 0x3c, 0x32, 0x15, 0xbe, 0x7a, 0xd1, 0xb6, 0xbf,
#   0xb4, 0xe6, 0x53, 0xbf, 0xb0, 0x16, 0x61, 0xbf, 0x82, 0x26, 0x43, 0xbf,
#   0x48, 0xc8, 0x5e, 0xbf, 0x6f, 0xd6, 0xc8, 0xbd, 0xf0, 0xb7, 0x63, 0xbf,
#   0x44, 0x65, 0x34, 0xbf, 0xc9, 0xd8, 0x0c, 0xbf, 0xfa, 0xfc, 0x2c, 0xbf,
#   0x44, 0xd3, 0x63, 0xbf, 0x51, 0x45, 0x1a, 0xbe, 0x40, 0xc2, 0x1b, 0xbf,
#   0x6a, 0x1a, 0x3d, 0xbf, 0x6e, 0xd0, 0x30, 0xbe, 0xb2, 0x27, 0x0c, 0xbe,
#   0xea, 0xb6, 0x08, 0xbf, 0x1a, 0x00, 0x00, 0x00, 0x73, 0x65, 0x71, 0x75,
#   0x65, 0x6e, 0x74, 0x69, 0x61, 0x6c, 0x2f, 0x63, 0x6f, 0x6e, 0x76, 0x32,
#   0x64, 0x5f, 0x31, 0x2f, 0x43, 0x6f, 0x6e, 0x76, 0x32, 0x44, 0x00, 0x00,
#   0x04, 0x00, 0x00, 0x00, 0x40, 0x00, 0x00, 0x00, 0x03, 0x00, 0x00, 0x00,
#   0x03, 0x00, 0x00, 0x00, 0x20, 0x00, 0x00, 0x00, 0xfa, 0xfd, 0xff, 0xff,
#   0x34, 0x00, 0x00, 0x00, 0x09, 0x00, 0x00, 0x00, 0x0c, 0x00, 0x00, 0x00,
#   0x04, 0x00, 0x00, 0x00, 0x14, 0xfd, 0xff, 0xff, 0x18, 0x00, 0x00, 0x00,
#   0x73, 0x65, 0x71, 0x75, 0x65, 0x6e, 0x74, 0x69, 0x61, 0x6c, 0x2f, 0x63,
#   0x6f, 0x6e, 0x76, 0x32, 0x64, 0x2f, 0x43, 0x6f, 0x6e, 0x76, 0x32, 0x44,
#   0x00, 0x00, 0x00, 0x00, 0x04, 0x00, 0x00, 0x00, 0x20, 0x00, 0x00, 0x00,
#   0x03, 0x00, 0x00, 0x00, 0x03, 0x00, 0x00, 0x00, 0x03, 0x00, 0x00, 0x00,
#   0x46, 0xfe, 0xff, 0xff, 0x34, 0x00, 0x00, 0x00, 0x08, 0x00, 0x00, 0x00,
#   0x0c, 0x00, 0x00, 0x00, 0x04, 0x00, 0x00, 0x00, 0x60, 0xfd, 0xff, 0xff,
#   0x19, 0x00, 0x00, 0x00, 0x73, 0x65, 0x71, 0x75, 0x65, 0x6e, 0x74, 0x69,
#   0x61, 0x6c, 0x2f, 0x64, 0x65, 0x6e, 0x73, 0x65, 0x5f, 0x31, 0x2f, 0x4d,
#   0x61, 0x74, 0x4d, 0x75, 0x6c, 0x00, 0x00, 0x00, 0x02, 0x00, 0x00, 0x00,
#   0x0a, 0x00, 0x00, 0x00, 0x40, 0x00, 0x00, 0x00, 0x22, 0xfe, 0xff, 0xff,
#   0x00, 0x00, 0x00, 0x09, 0x58, 0x00, 0x00, 0x00, 0x07, 0x00, 0x00, 0x00,
#   0x34, 0x00, 0x00, 0x00, 0x10, 0x00, 0x00, 0x00, 0x0c, 0x00, 0x0c, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x04, 0x00, 0x08, 0x00, 0x0c, 0x00, 0x00, 0x00,
#   0x14, 0x00, 0x00, 0x00, 0x04, 0x00, 0x00, 0x00, 0x01, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x01, 0x00, 0x00, 0x00,
#   0x50, 0x82, 0x07, 0x3c, 0x17, 0x00, 0x00, 0x00, 0x73, 0x65, 0x71, 0x75,
#   0x65, 0x6e, 0x74, 0x69, 0x61, 0x6c, 0x2f, 0x64, 0x65, 0x6e, 0x73, 0x65,
#   0x2f, 0x4d, 0x61, 0x74, 0x4d, 0x75, 0x6c, 0x00, 0x02, 0x00, 0x00, 0x00,
#   0x40, 0x00, 0x00, 0x00, 0x00, 0x09, 0x00, 0x00, 0xf6, 0xfe, 0xff, 0xff,
#   0x4c, 0x00, 0x00, 0x00, 0x06, 0x00, 0x00, 0x00, 0x0c, 0x00, 0x00, 0x00,
#   0x04, 0x00, 0x00, 0x00, 0x10, 0xfe, 0xff, 0xff, 0x31, 0x00, 0x00, 0x00,
#   0x73, 0x65, 0x71, 0x75, 0x65, 0x6e, 0x74, 0x69, 0x61, 0x6c, 0x2f, 0x63,
#   0x6f, 0x6e, 0x76, 0x32, 0x64, 0x2f, 0x42, 0x69, 0x61, 0x73, 0x41, 0x64,
#   0x64, 0x2f, 0x52, 0x65, 0x61, 0x64, 0x56, 0x61, 0x72, 0x69, 0x61, 0x62,
#   0x6c, 0x65, 0x4f, 0x70, 0x2f, 0x72, 0x65, 0x73, 0x6f, 0x75, 0x72, 0x63,
#   0x65, 0x00, 0x00, 0x00, 0x01, 0x00, 0x00, 0x00, 0x20, 0x00, 0x00, 0x00,
#   0x4e, 0xff, 0xff, 0xff, 0x4c, 0x00, 0x00, 0x00, 0x05, 0x00, 0x00, 0x00,
#   0x0c, 0x00, 0x00, 0x00, 0x04, 0x00, 0x00, 0x00, 0x68, 0xfe, 0xff, 0xff,
#   0x33, 0x00, 0x00, 0x00, 0x73, 0x65, 0x71, 0x75, 0x65, 0x6e, 0x74, 0x69,
#   0x61, 0x6c, 0x2f, 0x63, 0x6f, 0x6e, 0x76, 0x32, 0x64, 0x5f, 0x31, 0x2f,
#   0x42, 0x69, 0x61, 0x73, 0x41, 0x64, 0x64, 0x2f, 0x52, 0x65, 0x61, 0x64,
#   0x56, 0x61, 0x72, 0x69, 0x61, 0x62, 0x6c, 0x65, 0x4f, 0x70, 0x2f, 0x72,
#   0x65, 0x73, 0x6f, 0x75, 0x72, 0x63, 0x65, 0x00, 0x01, 0x00, 0x00, 0x00,
#   0x40, 0x00, 0x00, 0x00, 0xa6, 0xff, 0xff, 0xff, 0x4c, 0x00, 0x00, 0x00,
#   0x04, 0x00, 0x00, 0x00, 0x0c, 0x00, 0x00, 0x00, 0x04, 0x00, 0x00, 0x00,
#   0xc0, 0xfe, 0xff, 0xff, 0x30, 0x00, 0x00, 0x00, 0x73, 0x65, 0x71, 0x75,
#   0x65, 0x6e, 0x74, 0x69, 0x61, 0x6c, 0x2f, 0x64, 0x65, 0x6e, 0x73, 0x65,
#   0x2f, 0x42, 0x69, 0x61, 0x73, 0x41, 0x64, 0x64, 0x2f, 0x52, 0x65, 0x61,
#   0x64, 0x56, 0x61, 0x72, 0x69, 0x61, 0x62, 0x6c, 0x65, 0x4f, 0x70, 0x2f,
#   0x72, 0x65, 0x73, 0x6f, 0x75, 0x72, 0x63, 0x65, 0x00, 0x00, 0x00, 0x00,
#   0x01, 0x00, 0x00, 0x00, 0x40, 0x00, 0x00, 0x00, 0x00, 0x00, 0x0e, 0x00,
#   0x14, 0x00, 0x04, 0x00, 0x00, 0x00, 0x08, 0x00, 0x0c, 0x00, 0x10, 0x00,
#   0x0e, 0x00, 0x00, 0x00, 0x4c, 0x00, 0x00, 0x00, 0x03, 0x00, 0x00, 0x00,
#   0x0c, 0x00, 0x00, 0x00, 0x04, 0x00, 0x00, 0x00, 0x28, 0xff, 0xff, 0xff,
#   0x32, 0x00, 0x00, 0x00, 0x73, 0x65, 0x71, 0x75, 0x65, 0x6e, 0x74, 0x69,
#   0x61, 0x6c, 0x2f, 0x64, 0x65, 0x6e, 0x73, 0x65, 0x5f, 0x31, 0x2f, 0x42,
#   0x69, 0x61, 0x73, 0x41, 0x64, 0x64, 0x2f, 0x52, 0x65, 0x61, 0x64, 0x56,
#   0x61, 0x72, 0x69, 0x61, 0x62, 0x6c, 0x65, 0x4f, 0x70, 0x2f, 0x72, 0x65,
#   0x73, 0x6f, 0x75, 0x72, 0x63, 0x65, 0x00, 0x00, 0x01, 0x00, 0x00, 0x00,
#   0x0a, 0x00, 0x00, 0x00, 0x00, 0x00, 0x0e, 0x00, 0x18, 0x00, 0x08, 0x00,
#   0x07, 0x00, 0x0c, 0x00, 0x10, 0x00, 0x14, 0x00, 0x0e, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x02, 0x34, 0x00, 0x00, 0x00, 0x02, 0x00, 0x00, 0x00,
#   0x0c, 0x00, 0x00, 0x00, 0x04, 0x00, 0x00, 0x00, 0x94, 0xff, 0xff, 0xff,
#   0x18, 0x00, 0x00, 0x00, 0x73, 0x65, 0x71, 0x75, 0x65, 0x6e, 0x74, 0x69,
#   0x61, 0x6c, 0x2f, 0x66, 0x6c, 0x61, 0x74, 0x74, 0x65, 0x6e, 0x2f, 0x43,
#   0x6f, 0x6e, 0x73, 0x74, 0x00, 0x00, 0x00, 0x00, 0x01, 0x00, 0x00, 0x00,
#   0x02, 0x00, 0x00, 0x00, 0x14, 0x00, 0x18, 0x00, 0x04, 0x00, 0x00, 0x00,
#   0x08, 0x00, 0x0c, 0x00, 0x10, 0x00, 0x00, 0x00, 0x00, 0x00, 0x14, 0x00,
#   0x14, 0x00, 0x00, 0x00, 0x44, 0x00, 0x00, 0x00, 0x01, 0x00, 0x00, 0x00,
#   0x28, 0x00, 0x00, 0x00, 0x20, 0x00, 0x00, 0x00, 0x04, 0x00, 0x00, 0x00,
#   0x04, 0x00, 0x00, 0x00, 0xff, 0xff, 0xff, 0xff, 0x20, 0x00, 0x00, 0x00,
#   0x20, 0x00, 0x00, 0x00, 0x03, 0x00, 0x00, 0x00, 0x04, 0x00, 0x04, 0x00,
#   0x04, 0x00, 0x00, 0x00, 0x0c, 0x00, 0x00, 0x00, 0x63, 0x6f, 0x6e, 0x76,
#   0x32, 0x64, 0x5f, 0x69, 0x6e, 0x70, 0x75, 0x74, 0x00, 0x00, 0x00, 0x00,
#   0x04, 0x00, 0x00, 0x00, 0x01, 0x00, 0x00, 0x00, 0x20, 0x00, 0x00, 0x00,
#   0x20, 0x00, 0x00, 0x00, 0x03, 0x00, 0x00, 0x00, 0x05, 0x00, 0x00, 0x00,
#   0x60, 0x00, 0x00, 0x00, 0x44, 0x00, 0x00, 0x00, 0x28, 0x00, 0x00, 0x00,
#   0x14, 0x00, 0x00, 0x00, 0x04, 0x00, 0x00, 0x00, 0xd8, 0xff, 0xff, 0xff,
#   0x00, 0x00, 0x00, 0x19, 0x19, 0x00, 0x00, 0x00, 0xcc, 0xff, 0xff, 0xff,
#   0x00, 0x00, 0x00, 0x09, 0x09, 0x00, 0x00, 0x00, 0x09, 0x00, 0x00, 0x00,
#   0xf4, 0xff, 0xff, 0xff, 0x00, 0x00, 0x00, 0x16, 0x16, 0x00, 0x00, 0x00,
#   0x0c, 0x00, 0x0c, 0x00, 0x07, 0x00, 0x00, 0x00, 0x00, 0x00, 0x08, 0x00,
#   0x0c, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x11, 0x11, 0x00, 0x00, 0x00,
#   0x0c, 0x00, 0x10, 0x00, 0x07, 0x00, 0x00, 0x00, 0x08, 0x00, 0x0c, 0x00,
#   0x0c, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x03, 0x05, 0x00, 0x00, 0x00,
#   0x03, 0x00, 0x00, 0x00
# };
# unsigned int g_model_len = 177232;
